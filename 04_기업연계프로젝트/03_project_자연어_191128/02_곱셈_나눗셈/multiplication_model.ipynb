# %% [markdown]
# ## 곱셈
# * 곱셈 파일만 전에 만든 모델 적용 : answer_all
# * answer_all 파일에서 답 안나온 것, 틀린 것 채우는 모델 : answer_all_final_3

# %%
import pandas as pd
import numpy as np
import re
df=pd.read_excel("./data/math_func_type.xlsx",sheet_name=2)
df.head()
# Out:
#                                                   질문  \
# 0              곰 인형이 2개씩 6묶음 있습니다. 곰 인형은 모두 몇 개일까요?
# 1  연희네 모둠 학생들은 학급문고에 책을 1권 또는 2권씩 내기로 했습니다. 9명이 낸...
# 2  과일 가게에 복숭아가 8개씩 5묶음이 있고, 사과가 3개씩 9묶음이 있습니다. 과일...
# 3  책상 위에 색연필이 7자루씩 3묶음 있고, 사인펜이 4자루씩 8묶음 있습니다. 책상...
# 4  호진이는 4권씩 묶여 있는 연습장을 2묶음, 수연이는 호진이의 4배만큼 가지고 있습...
#
#                                수식풀이  \
# 0                          2×6=[12]
# 1    2×9=[18] ; 18-13=[5] ; 1×[5]=5
# 2  8×5=[40] ; 3×9=[27] ; 40+27=[67]
# 3  7×3=[21] ; 4×8=[32] ; 21+32=[53]
# 4    4×2=[8] ; 8×4=[32] ; 8+32=[40]
#
#                                           키워드                 키워드1
# 0                             2개씩 6묶음, 모두 몇 개              씩, 모두 몇
# 1      학생들, 1권 또는 2권씩, 9명, 13권, 1권 낸 학생, 몇 명                씩, 몇
# 2                    8개씩 5묶음, 3개씩 9묶음, 모두 몇 개           씩, 씩, 모두 몇
# 3                 7자루씩 3묶음, 4자루씩 8묶음, 모두 몇 자루           씩, 씩, 모두 몇
# 4  4권씩, 2묶음, 수연이는 호진이의 4배만큼, 호진이와 수연이, 모두 몇 권  씩, 는, 의, 만큼,  모두 몇

# %%
import platform

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# sns.set()

from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:
    print("It's unknown system. Hangul fonts are not supported!")
    
# plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["figure.figsize"] = [12,6]

# %matplotlib inline

# %%
# df.tail()

# %%
# from konlpy.tag import Kkma
# kkma = Kkma()

# from konlpy.tag import Okt
# okt = Okt()


# df["kkma"] = ''
# df["okt"] = ''


# for i in range(0, len(df)):
#     #df['kkma'][i] = kkma.morphs(df["질문"][i])
#     #df['okt'][i] = okt.morphs(df["질문"][i])
#     df['kkma'][i] = kkma.pos(df["질문"][i])
#     df['okt'][i] = okt.pos(df["질문"][i])
    
# df.head()

# %%
# df.to_excel("a3.xlsx",index=False)

# %%
import re

df["model"]=''
df["model_answer"]=''

for i in range(0,len(df)):
    if re.compile("[\d]{1,2}월 [\d]{1,2}일입니다. [\d]{1}주일 후는 몇 월 ['몇 일, 며칠']").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        k=int(a[2])*7+int(a[1])
        if a[0] in [1,3,5,7,8,10]:
            if int(k)>31:
                df['model_answer'][i]=str(int(a[0])+1)+"월"+str(int(k)-31)+"일"
            else: 
                df['model_answer'][i]=str(a[0])+"월"+str(k)+"일"
        elif a[0]==2:
            if int(k)>28:
                df['model_answer'][i]=str(int(a[0])+1)+"월"+str(int(k)-28)+"일"
            else: 
                df['model_answer'][i]=str(a[0])+"월"+str(k)+"일"
        elif a[0]==12:
            if int(k)>31:
                df['model_answer'][i]="1월"+str(int(k)-31)+"일"
            else: 
                df['model_answer'][i]=str(a[0])+"월"+str(k)+"일"
        else:
            if int(k)>30:
                df['model_answer'][i]=str(int(a[0])+1)+"월"+str(int(k)-30)+"일"
            else: 
                df['model_answer'][i]=str(a[0])+"월"+str(k)+"일"

df['model_answer'][31]
# Out:
# '7월22일'

# %%
# df.columns
# df.head()

# %%
for i in range(0,len(df)):
    if re.compile("[\d]{1,2}주일입니다.").findall(df["질문"][i]) and re.compile("모두 며칠").findall(df["질문"][i]):
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df['model'][i]=a
        df['model_answer'][i]=str(int(a[0])*7)+"일"
df['model_answer'][21]
# Out:
# '35일'

# %%
# df.columns
# df.head()

# %%
for i in range(0,len(df)):
    a=re.compile("[\d]{1,4}").findall(df["질문"][i])
    if (re.compile("씩").findall(df["질문"][i])!=[]) and (re.compile("모두").findall(df["질문"][i])!=[]) and  (len(a)==2):
        df['model_answer'][i]=int(a[0])*int(a[1])
    elif (re.compile("[\d]{1,2}[\w]{1,3}에 [\d]{1,2}[\w]{1,3}씩").findall(df["질문"][i])!=[]) and (re.compile("모두").findall(df["질문"][i])!=[]) and  (len(a)==2):
        df['model_answer'][i]=int(a[0])*int(a[1])
        
    elif (re.compile("씩").findall(df["질문"][i])!=[]) and (re.compile("모두").findall(df["질문"][i])!=[]) and (len(a)==4):
        df['model_answer'][i]=int(a[0])*int(a[1])+int(a[2])*int(a[3])
    elif (re.compile("[\d]{1,2}[\w]{1,3}에 [\d]{1,2}[\w]{1,3}씩").findall(df["질문"][i])!=[]) and (re.compile("모두").findall(df["질문"][i])!=[]) and (len(a)==4):
        df['model_answer'][i]=int(a[0])*int(a[1])+int(a[2])*int(a[3])

    elif (re.compile("씩").findall(df["질문"][i])!=[]) and  (re.compile("[\d]{1,4}[\w]{1,4}씩 몇").findall(df["질문"][i])!=[]) and ((re.compile("묶으면").findall(df["질문"][i])!=[]) or (re.compile("모두").findall(df["질문"][i])!=[]) or (re.compile("묶는다면").findall(df["질문"][i])!=[]) or (re.compile("포장한다면").findall(df["질문"][i])!=[])) and (len(a)==3):
        df['model_answer'][i]=(int(a[0])*int(a[1]))/int(a[2])
    elif (re.compile("씩").findall(df["질문"][i])!=[]) and  (re.compile("몇[\w]{1,4}씩 [\d]{1,4}").findall(df["질문"][i])!=[]) and (re.compile("묶").findall(df["질문"][i])!=[]) and (len(a)==3):
        df['model_answer'][i]=(int(a[0])*int(a[1]))/int(a[2])


    elif (re.compile('중').findall(df["질문"][i])!=[]) and (re.compile("[\d]{1,2}[\w]{1,3}씩 [\d]{1,2}[\w]{1,15} 나누어").findall(df["질문"][i])!=[]) and (re.compile("남은").findall(df["질문"][i])!=[]) and (len(a)==3):
        k=max(a)
        del a[a.index(max(a))]
        if int(k)>(int(a[0])*int(a[1])):
            df['model_answer'][i]=int(k)-int(a[0])*int(a[1])

 
    elif (re.compile("[\d]{1,2}[\w]{1,3}씩[\w]{0,20} [\d]{1,2}").findall(df["질문"][i])!=[]) and (re.compile("모두 몇").findall(df["질문"][i])!=[]) and (re.compile("의 [\d]{1,2}배만큼").findall(df["질문"][i])!=[]) and (len(a)==3):
        df['model_answer'][i]=int(a[0])*int(a[1])*int(a[2])
        

    print(i,df["질문"][i],df['model_answer'][i])
# Out:
# 0 곰 인형이 2개씩 6묶음 있습니다. 곰 인형은 모두 몇 개일까요?  12
# 1 연희네 모둠 학생들은 학급문고에 책을 1권 또는 2권씩 내기로 했습니다. 9명이 낸 책이 13권이라면 그중에서 책을 1권 낸 학생은 몇 명입니까?
# 2 과일 가게에 복숭아가 8개씩 5묶음이 있고, 사과가 3개씩 9묶음이 있습니다. 과일 가게에 있는 복숭아와 사과는 모두 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.  67
# 3 책상 위에 색연필이 7자루씩 3묶음 있고, 사인펜이 4자루씩 8묶음 있습니다. 책상 위에 있는 색연필과 사인펜은 모두 몇 자루입니까?  53
# 4 호진이는 4권씩 묶여 있는 연습장을 2묶음, 수연이는 호진이의 4배만큼 가지고 있습니다. 호진이와 수연이가 가지고 있는 연습장은 모두 몇 권인지 구하시오.
# 5 연필이 70자루 있습니다. 이 연필을 7자루씩 6명에게 나누어 주었습니다. 남은 연필은 몇 자루인지 풀이 과정을 쓰고, 답을 구하시오.
# 6 운동장에 6명씩 앉을 수 있는 긴 의자가 7개, 5명씩 앉을 수 있는 긴 의자가 8개 있습니다. 학생 86명이 모두 긴 의자에 앉으려고 하니 의자가 부족해 나머지 학생들은 1명씩 앉을 수 있는 의자에 앉으려고 합니다. 1명씩 앉는 의자는 몇 개 필요합니까?
# 7 사탕이 모두 35개 있었습니다. 그 중에서 4개씩 6봉지를 만들어 친구에게 주었습니다. 남은 사탕은 몇 개입니까?
# 8 오늘은 8월 1일입니다. 3주일 후는 몇 월 몇 일입니까?  8월22일
# 9 사탕이 6개씩 6묶음 있습니다. 이것을 9개씩 묶으면 몇 묶음이 됩니까?
# 10 사탕이 6개씩 6묶음 있습니다. 이것을 4개씩 묶으면 몇 묶음인지 구하시오.
# 11 딱지가 6장씩 4묶음 있습니다. 이 딱지를 3장씩 묶는다면, 모두 몇 묶음이 됩니까?
# 12 문구점에 종이 상자가 9개 있습니다. 4개의 상자에는 한지가 5묶음씩 들어 있고, 3개의 상자에는 포장지가 4묶음씩 들어 있고, 나머지 2개의 상자에는 색종이가 8묶음씩 들어 있습니다. 문구점 아저씨가 오늘 팔 종이를 각 상자에서 2묶음씩 꺼냈다면, 상자에 남은 종이 묶음은 모두 몇 묶음입니까?
# 13 예림이네 학교 운동회에서 이어달리기를 하려고 합니다. 청팀과 백팀이 각각 8명씩이며 이긴 팀의 선수들에게는 공책 3권씩, 진 팀의 선수들에게는 공책 2권씩을 주려고 합니다. 공책은 모두 몇 권 필요합니까?
# 14 과일 가게에 6개씩 들어 있는 참외가 4상자 있습니다. 가게 주인이 참외를 2상자 더 들여왔습니다. 과일 가게에 있는 참외는 모두 몇 개입니까?
# 15 책을 5권씩 넣어 포장할 수 있는 상자가 7개 있습니다. 같은 책을 42권 포장하려고 할 때, 포장하고 남는 책은 몇 권입니까?
# 16 구슬이 4개씩 담긴 주머니가 5개 있습니다. 구슬은 모두 몇 개입니까?  20
# 17 풍선이 5개씩 6묶음 있습니다. 풍선은 모두 몇 개입니까?  30
# 18 준영이네 학교의 겨울 방학은 6주일입니다. 겨울 방학은 모두 며칠입니까?  42일
# 19 정아네 반 학생들은 6명씩 6모둠입니다. 실험을 하기 위해서 4명씩 한 모둠으로 하려고 합니다. 4명씩 몇 모둠이 됩니까?
# 20 사탕이 4개씩 6묶음이 있습니다. 이 사탕을 8개씩 묶는다면 모두 몇 묶음이 됩니까?
# 21 하영이네 학교의 여름 방학은 5주일입니다. 여름 방학은 모두 며칠입니까?  35일
# 22 채연이는 문구점에서 색종이를 8장씩 5묶음을 샀습니다. 채연이가 산 색종이는 모두 몇 장입니까?  40
# 23 과일 상자 안에 배가 3개씩 5봉지 들어 있고, 감이 7개씩 4봉지 들어 있습니다. 과일 상자에 들어 있는 배와 감은 모두 몇 개입니까?  43
# 24 백화점에 인형 상자 6개가 있습니다. 4개의 상자에는 강아지 인형이 6개씩 들어 있고, 2개의 상자에는 토끼 인형이 7개씩 들어 있습니다. 상자에 들어 있는 인형은 모두 몇 개입니까?
# 25 어머니께서 귤을 9개씩 4봉지, 사과를 8개씩3봉지 사셨습니다. 한 접시에 귤은 6개씩, 사과는 4개씩 담는다면, 접시는 모두 몇 개가 필요합니까? (단, 귤과 사과를 따로 담습니다.)
# 26 수영이는 공책을 7권씩 4묶음을 만들고 한 묶음을 더 만들려고 하는데 3권이 부족합니다. 수영이가 가지고 있는 공책은 몇 권입니까?
# 27 사탕을 2개씩 6봉지로 포장하였습니다. 이 사탕을 다시 3개씩 포장한다면, 몇 봉지가 됩니까?
# 28 오늘은 6월 1일입니다. 3주일 후는 몇 월 몇 일입니까?  6월22일
# 29 연주네 반 학생은 37명입니다. 5명씩 짝짓기를 하면 짝을 짓지 못하는 학생은 몇 명입니까?
# 30 군밤이 6개씩 들어 있는 봉지가 5봉지 있습니다. 이 중 몇 개를 먹고 남은 것이 13개라면, 먹은 군밤은 몇 개 입니까?
# 31 오늘은 7월 1일입니다. 3주일 후는 몇 월 며칠입니까?  7월22일
# 32 무한도전 조정팀은 지난 2011년 제53회 전국조정 선수권 대회 에이트 2,000m 노비스 대회에 출전해 8분 2초대의 기록으로 8개 팀 중 8위를 차지했습니다. 조정 경기 종목 중 에이트는 노를 젓는 8명의 선수와 방향을 조정하는 한 명의 선수가 배에 타고 경기를 합니다. 이 날 경기에 참여한 선수는 모두 몇 명입니까?
# 33 연희는 이벤트에 당첨이 되어 사이다 8개씩 6상자를 받았습니다. 연희네 반은 모두 36명이고, 1개씩 나눠 가진 후 나머지는 연희가 집에 가져가려고 합니다. 연희가 갖게 되는 음료수는 모두 몇 개입니까?  84
# 34 운동장에 6명씩 앉을 수 있는 의자가 9개, 4명씩 앉을 수 있는 의자가 7개 있습니다. 학부모 91명이 모두 의자에 앉으려면 1명씩 앉을 수 있는 의자는 몇 개 필요합니까?
# 35 문구점에 빨간색 색연필은 5자루씩 8통 있고 파란색 색연필은 9자루씩 4통 있습니다. 이 중에서 빨간색 색연필 18자루와 파란색 색연필 23자루를 팔았다면 남은 색연필은 몇 자루입니까?
# 36 영미는 생일잔치에 친구 5명을 초대했습니다. 초대한 친구들에게 각각 사탕 2개와 과자 3개씩을 주었습니다. 영미가 친구들에게 준 사탕과 과자는 모두 몇 개입니까?
# 37 빵이 5개씩 들어 있는 봉지가 6봉지 있습니다. 그 중에서 2봉지를 먹었습니다. 남아 있는 빵은 모두 몇 개입니까?
# 38 빨간색 주머니에는 구슬이 5개씩, 파란색 주머니에는 구슬이 2개씩 들어있습니다. 빨간색 주머니 5개와 파란색 주머니 6개에 들어있는 구슬은 모두 몇 개입니까?  40
# 39 민경이네 반 어린이들이 2명씩 9대의 자전거에 탔더니 7명이 남았습니다. 민경이네 반 어린이들을 5명씩 한 모둠으로 하면 모두 몇 개의 모둠이 됩니까?  53
# 40 바퀴가 4개인 자동차가 6대 있습니다. 자동차 바퀴의 수를 곱셈식으로 나타내어 보세요. 4의 □배
# 41 빵이 한 봉지에 2개씩 들어있습니다. 8봉지에 들어 있는 빵은 모두 몇 개일까요?  16
# 42 달리기 경기에서 1등은 3점, 2등은 2점, 3등은 1점을 얻습니다. 준기네 반에는 1등이 6명, 2등이 1명, 3등이 5명 있습니다. 준기네 반의 달리기 점수는 모두 몇 점일까요?
# 43 과일 가게에서 사과는 한 상자에 9개씩, 배는 한 상자에 6개씩 담아서 팔고 있습니다. 아버지께서는 사과 3상자와 배 4상자를 사 오셨습니다. 아버지께서 사 오신 과일은 모두 몇 개일까요?  66
# 44 접시 하나에 당근이 4개씩 있습니다. 접시 5개에 있는 당근은 모두 몇 개인지 곱셈식으로 나타내어 보세요.  20
# 45 문어의 다리는 8개입니다. 문어 7마리의 다리는 모두 몇 개인지 곱셈식으로 나태내어 보세요.
# 46 한 사람이 공깃돌을 5개씩 가지고 있습니다. 7명이 가지고 있는 공깃돌은 모두 몇 개인지 곱셈식으로 알아보세요.  35
# 47 공 꺼내기 놀이에서 0점짜리 공 3개, 1점짜리 공 2개, 2점짜리 공 3개, 3점짜리 공 5개,  4점짜리 공 2개를 꺼냈습니다. 꺼낸 공의 점수는 모두 몇 점일까요?
# 48 3명의 친구들이 가위바위보를 하여 모두 보를 냈습니다. 펼친 손가락은 모두 몇 개입니까?
# 49 진경이가 한 상자의 높이를 뼘으로 재었더니 4뼘이었습니다. 7상자의 높이는 진경이의 뼘으로 모두 몇 뼘인지 풀이 과정을 쓰고, 답을 구하시오.
# 50 삼각형 6개, 사각형 9개의 변의 수의 합은 모두 몇 개인지 구하시오.
# 51 한 자루에 호박을 8개씩 담아 파는 상점이 있습니다. 어머니께서 어제 이 상점에서 호박을 6자루 사고, 오늘은 3자루를 샀습니다. 어머니께서 어제와 오늘 산 호박은 모두 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.
# 52 수지는 사탕 25개를 가지고 있습니다. 한 상자에 사탕을 6개씩 담아 모두 7상자를 만들려면 사탕은 몇 개가 더 필요한지 풀이 과정을 쓰고, 답을 구하시오.
# 53 빵이 한 봉지에 8개씩 3봉지 있습니다. 이 빵을 모두 꺼내어 다시 한 봉지에 6개씩 담으면 몇 봉지가 되는지 풀이 과정을 쓰고, 답을 구하시오.
# 54 6명의 어린이가 가위바위보를 했습니다. 그중 2명의 어린이가 가위를 내서 이겼을 때, 6명의 어린이가 펼친 손가락은 모두 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.
# 55 문어 한 마리의 다리는 8개입니다. 문어 6마리의 다리는 모두 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.
# 56 인영이의 친구들이 한 사람당 딱지를  3장씩 3묶음 가지고 있습니다. 8명의 친구들이 가지고 있는 딱지는 모두 몇 장인지 풀이 과정을 쓰고, 답을 구하시오.
# 57 울타리 하나에 기둥이 8개 있습니다. 울타리 7개를 이어 오리 집을 만들었습니다. 기둥은 모두 몇 개입니까?
# 58 참외가 한 접시에 9개씩 7접시 있었습니다. 그중에서 3접시를 먹었다면 남은 참외는 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.
# 59 도희는 매일 물을 2병씩 마십니다. 도희가 7일 동안 마시는 물은 모두 몇 병인지 곱셈식으로 나타내시오.  14
# 60 농구는 5명의 선수가 한 팀이 되어 경기를 합니다. 8팀의 선수는 모두 몇 명인지 풀이 과정을 쓰고, 답을 구하시오.
# 61 지우개 한 개의 길이는 3cm입니다. 지우개 5개의 길이는 몇 cm입니까?
# 62 도넛이 한 상자에 6개씩 들어 있습니다. 8상자에 들어 있는 도넛은 모두 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.  48
# 63 한 장의 길이가 4cm인 색 테이프 4장을 그림과 같이 겹치지 않게 이어 붙였습니다. 이어 붙인 색 테이프의 전체 길이는 몇 cm인지 풀이 과정을 쓰고, 답을 구하시오.
# 64 책꽂이 한 칸에 책이 7권씩 꽂혀 있습니다. 책꽂이 9칸에는 책이 모두 몇 권 꽂혀 있습니까?  63
# 65 한 판에 만두가 8개씩 있습니다. 5판에는 만두가 모두 몇 개 있습니까?  40
# 66 석현이는 친구들에게 펜을 1자루씩 선물하려고 합니다. 친구 6명에게 선물하려면 펜은 모두 몇 자루 필요한지 풀이 과정을 쓰고, 답을 구하시오.  6
# 67 사과가 열리지 않은 사과나무가 5그루 있습니다. 이 사과나무에 열린 사과는 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.
# 68 귤이 한 바구니에 7개씩 담겨 있습니다. 바구니 6개에 담겨 있는 귤은 모두 몇 개인지 곱셈식을 이용하여 구하시오.  42
# 69 회전 그네를 한 번 운행할 때 6명씩 탈 수 있습니다. 8번 운행하면 몇 명까지 탈 수 있는지 곱셈식을 이용하여 구하시오.
# 70 수현이는 노란색 구슬을 한 상자에 8개씩 4상자, 분홍색 구슬을 35개 가지고 있습니다. 수현이가 가지고 있는 구슬은 모두 몇 개입니까?
# 71 두발자전거 2대와 세발자전거 3대가 있습니다. 자전거의 바퀴는 모두 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.
# 72 한 통에 4개씩 들어 있는 껌이 9통 있습니다. 이 중에서 3통을 친구들에게 나누어 주었다면 남은 껌은 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.
# 73 승합차 한 대에 8명씩 탈 수 있습니다. 승합차 9대에는 모두 몇 명이 탈 수 있는지 곱셈식으로 알아보려고 합니다. 풀이 과정을 쓰고, 답을 구하시오.  72
# 74 오토바이 3대와 승용차 2대가 있습니다. 바퀴는 모두 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.
# 75 필통 한 개에 연필이 5자루씩 들어 있습니다. 필통 3개에 들어 있는 연필은 모두 몇 자루인지 풀이 과정을 쓰고, 답을 구하시오.  15
# 76 자동차 6대가 있습니다. 자동차의 바퀴 수는 모두 몇 개인지 곱셈식을 써 보세요.
#
# □×□=□
# 77 귤이 한 봉지에 8개씩 들어 있습니다. 7봉지 속에 들어 있는 귤은 모두 몇 개입니까?  56
# 78 미연이는 과녁 맞히기를 했습니다. 0점을 2번, 1점을 2번, 3점을 3번 맞혔습니다. 미연이가 얻은 점수는 모두 몇 점입니까?
# 79 재호는 하루에 4시간씩 일주일 동안 공부를 했습니다. 재호가 공부한 시간은 모두 몇 시간입니까?
# 80 25는 5의 몇 배일까요?
# 81 지우 동생의 나이는 3살입니다. 지우의 나이는 동생의 나이의 3배입니다. 지우의 나이는 몇 살일까요?
# 82 성윤이와 지은이의 대화를 읽고 지은이가 쌓은 모형은 모두 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.
# 성윤 : 모형 5개를 쌓았어.
# 지은 : 나는 네가 쌓은 모형 수의 5배만큼 쌓았어.
# 83 장미를 은영이는 6송이씩 3묶음 가지고 있고, 혜란이는 7송이씩 2묶음 가지고 있습니다. 두 사람 중에서 장미를 더 많이 가지고 있는 사람은 누구입니까?
# 84 ㉠과 ㉡의 차를 구하려고 합니다. 풀이 과정을 쓰고, 답을 구하시오.
#
# ▶ 6의 9배는 ㉠입니다.
#
# ▶ 8의 ㉡배는 40입니다.
# 85 주차장에 바퀴가 4개인 승용차가 6대, 바퀴가 2개인 오토바이가 9대 있습니다. 승용차와 오토바이 중 어느 것의 바퀴가 몇 개 더 많습니까?
# 86 색연필을 지후는 8자루 가지고 있고 유민이는 지후의 6배만큼 가지고 있습니다. 유민이가 가지고 있는 색연필은 몇 자루입니까?
# 87 곱셈구구를 이용하여 두 사람이 가지고 있는 귤의 수를 비교하시오.
#
# 민정 : 7개씩 3봉지
#
# 혜인 : 3개씩 7봉지
# 88 사과 5개씩 8묶음은 사과 8개씩 몇 묶음과 같습니까?
# 89 어떤 수에 9를 곱해야 할 것을 잘못하여 6을 곱했더니 42가 되었습니다. 바르게 계산한 값을 구하시오.
# 90 삼각형이 6개, 사각형이 4개 있습니다. 변의 수는 어느 도형이 몇 개 더 많은지 풀이 과정을 쓰고, 답을 구하시오.
# 91 민서는 문제집을 하루에 5쪽씩 4일 동안 풀었습니다. 민서와 같은 양을 소희는 하루에 4쪽씩 푼다면 며칠 동안 풀어야 합니까?
# 92 사각형 8개와 오각형 7개가 있습니다. 전체 꼭짓점의 수는 어느 도형이 몇 개 더 많습니까?
# 93 성현이의 나이는 9살입니다. 어머니의 나이는 성현이의 나이의 4배보다 3살 더 많습니다. 어머니는 성현이보다 몇 살 더 많은지 풀이 과정을 쓰고, 답을 구하시오.
# 94 사과는 8개 있고 참외는 사과의 3배만큼 있습니다. 참외는 모두 몇 개인지 덧셈식을 쓰고 답을 구하시오.
# 95 서연이와 민경이 중에서 스티커를 누가 몇 장 더 많이 가지고 있습니까?
#
# 서연 : 난 스티커를 4의 7배만큼 가지고 있어.
#
# 민경 : 난 스티커를 8장씩 3묶음을 가지고 있어.
# 96 지효는 종이배를 하루에 5개씩 6일 동안 접었고, 미진이는 하루에 지효가 접는 종이배의 수보다 2개씩 많게 일주일 동안 접었습니다. 두 사람이 접은 종이배는 모두 몇 개입니까?
# 97 태영이는 빨간 색종이 4장, 파란 색종이 3장을 가지고 있습니다. 지호는 태영이가 가진 색종이의 3배를 가지고 있습니다. 지호는 색종이를 몇 장 가지고 있을까요?
# 98 민기는 하루에 3쪽씩 수학 문제집을 풉니다. 서연이는 하루에 민기가 푸는 수학 문제집의 쪽수의 2배만큼 풉니다. 일주일 동안 서연이는 민기보다 몇 쪽 더 많이 풉니까?
# 99 송이네 집에는 2개의 꽃병에 꽃이 3송이씩 꽂혀 있습니다. 교실에 있는 꽃은 송이네 집 꽃의 5배입니다. 교실에 있는 꽃은 모두 몇 송이입니까?
# 100 영호는 구슬 7개를 가지고 있습니다. 기철이가 가지고 있는 구슬의 수는 영호가 가지고 있는 구슬의 수의 4배입니다. 기철이가 가지고 있는 구슬은 모두 몇 개입니까?
# 101 정은이는 엽서를 3장씩 2묶음 가지고 있습니다. 정은이의 언니는 정은이가 가지고 있는 엽서의 5배를 가지고 있습니다. 정은이 언니가 가지고 있는 엽서는 몇 장입니까?
# 102 현우는 딱지를 7장 가지고 있습니다. 규진이는 딱지를 현우의 3배만큼 가지고 있습니다. 규진이가 가지고 있는 딱지는 모두 몇 장입니까?
# 103 여학생은 5명씩 5줄로 서 있고, 남학생은 7명씩 4줄로 서 있습니다. 여학생과 남학생 중 누가 몇 명 더 많습니까?
#
# (          )이 (          )명 더 많습니다.
# 104 떡이 8개씩 3접시 있습니다. 이 떡을 다시 한 접시에 6개씩 담으려고 합니다. 접시가 처음보다 몇 개 더 필요합니까?
# 105 은주는 구슬을 7개 가지고 있습니다. 오빠가 가진 구슬은 은주가 가진 구슬의 4배입니다. 오빠가 가진 구슬은 몇 개입니까?
# 106 동생의 나이는 3살이고, 내 나이는 동생 나이의 2배보다 2살 더 많습니다. 오빠의 나이는 내 나이의 2배라면, 오빠는 몇 살입니까?
# 107 주석이는 붙임 딱지를 6장씩 3묶음 가지고 있고, 용찬이는 4장씩 5묶음 가지고 있습니다. 누가 몇 장 더 많이 가지고 있습니까?
# 108 연아는 색종이를 6장 가지고 있습니다. 동생은 연아의 4배보다 9장 더 많이 가지고 있다면, 두 사람이 가지고 있는 색종이는 모두 몇 장입니까?
# 109 인혜는 구슬을 4개 가지고 있습니다. 재훈이는 구슬을 인혜의 4배만큼 가지고 있습니다. 재훈이가 가지고 있는 구슬은 모두 몇 개입니까?
# 110 8씩 5묶음은 8의 4배보다 몇 큰 수인지 풀이 과정을 쓰고 답을 구하세요.
# 111 나현이는 9살입니다. 아버지의 나이는 나현이 나이의 5배보다 6살 더 적습니다. 아버지의 나이는 몇 살입니까?
# 112 사탕을 소희는 6개씩 6묶음 가지고 있고, 진수는 7개씩 5묶음 가지고 있습니다. 사탕을 더 많이 가지고 있는 사람은 누구입니까?
# 113 승애는 색종이를 4장씩 2묶음 가지고 있고, 택림이는 승애가 가지고 있는 색종이의 5배를 가지고 있습니다. 택림이가 가지고 있는 색종이는 모두 몇 장입니까?
# 114 밭에서 호박, 오이, 고추를 따 왔습니다. 따 온 호박은 3개이고, 오이는 호박의 3배만큼, 고추는 오이의 4배만큼 따 왔습니다. 밭에서 따온 호박, 오이, 고추는 모두 몇 개입니까?
# 115 진우는 구슬을 4개씩 5묶음 가지고 있고, 찬호는 3개씩 7묶음 가지고 있습니다. 누가 구슬을 몇 개 더 가지고 있습니까?
#
# (      )가 (      )개 더 가지고 있습니다.
# 116 초콜릿을 태민이는 6개씩 7묶음을 가지고 있고, 혜성이는 8개씩 5묶음을 가지고 있습니다. 초콜릿을 더 많이 가지고 있는 사람은 누구입니까?
# 117 민지는 초콜릿을 3개씩 8봉지 담았고, 윤지는 4개씩 9봉지 담았습니다. 초콜릿을 더 많이 담은 사람은 누구입니까?
# 118 희진이는 파란 구슬 3개, 노란 구슬 6개를 가지고 있습니다. 민경이는 희진이가 가지고 있는 구슬의 3배보다 4개 더 많이 가지고 있고, 현주는 민경이가 가지고 있는 구슬의 개수보다 8개 더 적게 가지고 있습니다. 세 사람이 가지고 있는 구슬의 수는 모두 몇 개입니까?
# 119 신영이는 꽃을 3송이씩 2묶음 가지고 있습니다. 선주는 신영이가 가지고 있는 꽃의 3배를 가지고 있고, 희수는 선주가 가지고 있는 꽃보다 9송이 더 가지고 있습니다. 신영, 선주, 희수가 가지고 있는 꽃은 모두 몇 송이입니까?  33

# %%
# df.columns
# df.head()

# %%
for i in range(0,len(df)):
    a=re.compile("[\d]{1,4}").findall(df["질문"][i])
    if (re.compile("중|그중|그 중에서|이 중|이 중에서|중에서").findall(df["질문"][i])!=[]) and (re.compile("[\d]{1,2}[\w]{1,3}씩 [\d]{1,2}[\w]{1,15} 나누어").findall(df["질문"][i])!=[]) and (re.compile("남은").findall(df["질문"][i])!=[]) and (len(a)==3):
        k=max(a)
        del a[a.index(max(a))]
        if int(k)>(int(a[0])*int(a[1])):
            df['model_answer'][i]=int(k)-int(a[0])*int(a[1])
            
         
    elif (re.compile("[\d]{1,2}[\w]{1,3}씩[\w]{0,20} [\d]{1,2}").findall(df["질문"][i])!=[]) and (re.compile("모두 몇").findall(df["질문"][i])!=[]) and (re.compile("의 [\d]{1,2}배만큼").findall(df["질문"][i])!=[]) and (len(a)==3):
        df['model_answer'][i]=int(a[0])*int(a[1])*int(a[2])

# %%
for i in range(0,len(df)):
    a=re.compile("[\d]{1,4}").findall(df["질문"][i])
    if (re.compile("[\d]{1,2}[\w]{1,4}씩[\w]{0,20} [\d]{1,2}[\w]{1,4}").findall(df["질문"][i])!=[]) and (re.compile("[나머지, 남은]").findall(df["질문"][i])!=[]) and (re.compile("모두 몇").findall(df["질문"][i])!=[]) and (re.compile("1[\w]{1,4}씩").findall(df["질문"][i])!=[]) and (len(a)==4):
        del a[a.index("1")]
        for d in range(0,len(a)):
            a[d]=int(a[d])
        k=max(a)
        del a[a.index(max(a))]
        if int(k)>(int(a[0])*int(a[1])):
            df['model_answer'][i]=int(k)-(int(a[0])*int(a[1]))
        else: df['model_answer'][i]=(int(a[0])*int(a[1]))-int(k)

        
df['model_answer'][33]
#df['질문'][33]
# Out:
# 12

# %%
for i in range(0,len(df)):
    a=re.compile("[\d]{1,4}").findall(df["질문"][i])
    if (re.compile("씩").findall(df["질문"][i])!=[]) and (len(a)==3) and  (re.compile("[\d]{1,4}[\w]{1,4}씩 ['묶으면, 묶는다면, 포장한다면, 포장하면']몇").findall(df["질문"][i])!=[]) and (re.compile("['모두, 묶으면, 묶는다면, 포장한다면, 포장하면']").findall(df["질문"][i])!=[]): 
        df['model_answer'][i]=(int(a[0])*int(a[1]))/int(a[2])
    elif (re.compile("씩").findall(df["질문"][i])!=[]) and (len(a)==3) and  (re.compile("[\d]{1,4}[\w]{1,4}씩 몇[\w]{1,4}").findall(df["질문"][i])!=[]): 
        df['model_answer'][i]=(int(a[0])*int(a[1]))/int(a[2])
    elif (re.compile("씩").findall(df["질문"][i])!=[]) and (len(a)==3) and  (re.compile("몇[\w]{1,4}씩").findall(df["질문"][i])!=[]) and (re.compile("['라면, 모두, 묶으면, 묶는다면, 포장한다면, 포장하면']").findall(df["질문"][i])!=[]):
        df['model_answer'][i]=(int(a[0])*int(a[1]))/int(a[2])    
df['model_answer'][27]
#df['질문'][20]
# Out:
# ''

# %%
for i in range(0,len(df)):
    a=re.compile("[\d]{1,4}").findall(df["질문"][i])
    if (re.compile(" [\d]{1,2}[\w]{1,3}씩 [\d]{1,2}[\w]{1,3}").findall(df["질문"][i])!=[]) and (len(a)==4) and (re.compile("[\d]{1,4}[\w]{1,4}씩 한 [\w]{1,4}").findall(df["질문"][i])!=[]): 
            df['model_answer'][i]=(int(a[0])*int(a[1]))/int(a[2])
        
df['model_answer'][19]
# Out:
# 9.0

# %%
# df.columns
# df.head()

# %%
for i in range(0,len(df)):
    a=re.compile("[\d]{1,4}").findall(df["질문"][i])
    if (re.compile("[\d]{1,2}명씩 앉을 수 있는 의자가 [\d]{1,2}개, [\d]{1,2}명씩 앉을 수 있는 의자가 [\d]{1,2}개").findall(df["질문"][i])!=[]) and (re.compile("1명씩 앉을 수 있는 의자는 몇 개").findall(df["질문"][i])!=[]): 
        del a[a.index("1")]
        for d in range(0,len(a)):
            a[d]=int(a[d])
        k=max(a)
        del a[a.index(max(a))]
        if int(k)>(int(a[0])*int(a[1])+int(a[2])*int(a[3])):
            df['model_answer'][i]=int(k)-(int(a[0])*int(a[1])+int(a[2])*int(a[3]))
            
    elif (re.compile("[\d]{1,2}명씩 앉을 수 있는 의자가 [\d]{1,2}개, [\d]{1,2}명씩 앉을 수 있는 의자가 [\d]{1,2}개").findall(df["질문"][i])!=[]) and (re.compile("한명씩 앉을 수 있는 의자는 몇 개").findall(df["질문"][i])!=[]): 
        for d in range(0,len(a)):
            a[d]=int(a[d])
        k=max(a)
        del a[a.index(max(a))]
        if int(k)>(int(a[0])*int(a[1])+int(a[2])*int(a[3])):
            df['model_answer'][i]=int(k)-(int(a[0])*int(a[1])+int(a[2])*int(a[3]))
   
df['model_answer'][34]
#df['질문'][34]
# Out:
# 9

# %%
for i in range(0,len(df)):
    a=re.compile("[\d]{1,4}").findall(df["질문"][i])
    if (re.compile("1등은 [\d]{1}점, 2등은 [\d]{1}점, 3등은 [\d]{1}점").findall(df["질문"][i])!=[]) and (re.compile('1등이 [\d]{1,2}명, 2등이 [\d]{1,2}명, 3등이 [\d]{1,2}명').findall(df["질문"][i])!=[]) and (re.compile("모두 몇").findall(df["질문"][i])!=[]):
        df['model_answer'][i]=int(a[1])*int(a[-5])+int(a[2])*int(a[-3])+int(a[3])*int(a[-1])
    elif (re.compile("[\d]{1}점짜리 공 [\d]{1}개").findall(df["질문"][i])!=[]):
        b=re.compile("[\d]{1}점짜리 공 [\d]{1}개").findall(df["질문"][i])
        for j in range(0,len(b)):
            c1=[]
            c2=[]
            d1=re.compile("[\d]{1}점짜리").findall(b[j])
            d2=re.compile("공 [\d]{1}개").findall(b[j])
            c1.append(int(d1[0][0]))
            c2.append(int(d2[0][-2]))
        df['model_answer'][i]=0
        if len(c1)==len(c2):
            for q in range(0,len(c1)):
                df['model_answer'][i]=df['model_answer'][i]+(c1[q]*c2[q])
    elif (re.compile("[\d]{1}점을 [\d]{1}번").findall(df["질문"][i])!=[]):
        b=re.compile("[\d]{1}점을 [\d]{1}번").findall(df["질문"][i])
        for j in range(0,len(b)):
            c1=[]
            c2=[]
            d1=re.compile("[\d]{1}점을").findall(b[j])
            d2=re.compile("[\d]{1}번").findall(b[j])
            c1.append(int(d1[0][0]))
            c2.append(int(d2[0][0]))
        df['model_answer'][i]=0
        if len(c1)==len(c2):
            for q in range(0,len(c1)):
                df['model_answer'][i]=df['model_answer'][i]+(c1[q]*c2[q])
                                                   
df['model_answer'][42]
#df['질문'][42]
# Out:
# 30

# %%
# df.columns
# df.head()

# %%
re.compile("[\d]{1}점짜리 공 [\d]{1}개").findall(df["질문"][47])
# Out:
# ['0점짜리 공 3개', '1점짜리 공 2개', '2점짜리 공 3개', '3점짜리 공 5개', '4점짜리 공 2개']

# %%
for i in range(0,len(df)):
    a=re.compile("[\d]{1,4}").findall(df["질문"][i])
    if (re.compile("[\w]{1,2}각형[\w]{0,3} [\d]{1,2}개").findall(df["질문"][i])) and (re.compile("['변, 꼭지점, 각']의 수").findall(df["질문"][i])) and (re.compile("어느 도형이 몇 개").findall(df["질문"][i])):
        r1=["삼각형","사각형","오각형","육각형","칠각형","팔각형","구각형","십각형","십이각형","십오각형","십육각형","십팔각형","이십각형"]
        r2=[3,4,5,6,7,8,9,10,12,15,16,18,20]
        b=re.compile("[\w]{1,2}각형[\w]{0,3} [\d]{1,2}개").findall(df["질문"][i])
        c1=[]
        c2=[]
        for j in range(0,len(b)):
            d1=re.compile("[\d]{1,2}개").findall(b[j])
            c1.append(int(d1[0][0]))
            d2=re.compile("[\w]{1,2}각형").findall(b[j])
            c2.append(r2[r1.index(d2[0])])
        df['model_answer'][i]=c1[0]*c2[0]
        for q in range(1,len(c1)):
            if df['model_answer'][i] < c1[q]*c2[q]:
                df['model_answer'][i]=c1[q]*c2[q]
                
    elif (re.compile("[\w]{1,2}각형[\w]{0,3} [\d]{1,2}개").findall(df["질문"][i])) and (re.compile("['변, 꼭지점, 각']의 수의 합은").findall(df["질문"][i])) and (re.compile("모두 몇 개").findall(df["질문"][i])):
        r1=["삼각형","사각형","오각형","육각형","칠각형","팔각형","구각형","십각형","십이각형","십오각형","십육각형","십팔각형","이십각형"]
        r2=[3,4,5,6,7,8,9,10,12,15,16,18,20]
        b=re.compile("[\w]{1,2}각형[\w]{0,3} [\d]{1,2}개").findall(df["질문"][i])
        c1=[]
        c2=[]
        for j in range(0,len(b)):
            d1=re.compile("[\d]{1,2}개").findall(b[j])
            c1.append(int(d1[0][0]))
            d2=re.compile("[\w]{1,2}각형").findall(b[j])
            c2.append(r2[r1.index(d2[0])])
        df['model_answer'][i]=0
        for q in range(0,len(c1)):
            df['model_answer'][i]=df['model_answer'][i]+(c1[q]*c2[q])

    elif (re.compile("[\w]{1,10} [\d]{1,2}대").findall(df["질문"][i])) and (re.compile("바퀴").findall(df["질문"][i])):
        r1=["오토바이","오토바이가","승용차",'자동차', '승용차가','자동차가','세발자전거','두발자전거']
        r2=[2,2,4,4,4,4,3,2]
        b=re.compile("[\w]{1,10} [\d]{1,2}대").findall(df["질문"][i])
        c1=[]
        c2=[]
        for j in range(0,len(b)):
            d1=re.compile("[\d]{1,2}대").findall(b[j])
            c1.append(int(d1[0][0]))
            d2=re.compile("[\w]{1,10}").findall(b[j])
            c2.append(r2[r1.index(d2[0])])
        df['model_answer'][i]=0
        for q in range(0,len(c1)):
            df['model_answer'][i]=df['model_answer'][i]+(c1[q]*c2[q])

            
            
    elif (re.compile("[\w]{1,4} [\d]{1,2}마리의 다리는 모두 몇 개").findall(df["질문"][i])):
        r1=['문어','강아지','오리','염소','닭','토끼','문어의','강아지의','오리의','염소의','닭의','토끼의']
        r2=[8,4,3,4,3,4,8,4,3,4,3,4]
        b=re.compile("[\w]{1,4} [\d]{1,2}마리의 다리는 모두 몇 개").findall(df["질문"][i])
        c1=[]
        c2=[]
        for j in range(0,len(b)):
            d1=re.compile("[\d]{1,2}마리의 다리").findall(b[j])
            d11=re.compile("[\d]{1,2}").findall(d1[0])
            c1.append(int(d11[0]))
            d2=re.compile("[\w]{1,4}").findall(b[j])
            c2.append(r2[r1.index(d2[0])])
        print(i,c1,c2)
        for q in range(0,len(c1)):
            df['model_answer'][i]=(c1[q]*c2[q])

    elif  (re.compile("[\w]{1,4}의 다리를 세어 보니 모두 [\d]{1,3}개").findall(df["질문"][i])) and ((re.compile(" [\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i]))):
        r1=['문어','강아지','오리','염소','닭','토끼','문어의','강아지의','오리의','염소의','닭의','토끼의']
        r2=[8,4,3,4,3,4,8,4,3,4,3,4]
        b=re.compile("[\w]{1,4}의 다리를 세어 보니 모두 [\d]{1,3}개").findall(df["질문"][i])
        c1=[]
        c2=[]
        for j in range(0,len(b)):
            d1=re.compile("[\d]{1,3}개").findall(b[j])
            d11=re.compile("[\d]{1,3}").findall(d1[0])
            c1.append(int(d11[0]))
            d2=re.compile("[\w]{1,4}").findall(b[j])
            c2.append(r2[r1.index(d2[0])])
        print(i,c1,c2)
        
        for q in range(0,len(c1)):
            df['model_answer'][i]=(c1[q]//c2[q])
            
    elif  (re.compile("[\w]{1,4} [\d]{1,2}마리").findall(df["질문"][i])) and ((re.compile("[\w]{1,3}와 [\w]{1,3}의 다리 [\w]{0,2}를 ['세어 보니, 세었더니'] 모두 [\d]{1,3}개").findall(df["질문"][i]))) and (re.compile("[\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i])):
        r1=['문어','강아지','오리','염소','닭','토끼','문어의','강아지의','오리의','염소의','닭의','토끼의']
        r2=[8,4,3,4,3,4,8,4,3,4,3,4]
        b1=re.compile("[\w]{1,4} [\d]{1,2}마리").findall(df["질문"][i])
        b2=re.compile("[\w]{1,4}와 [\w]{1,3}의 다리 [\w]{0,2}를 ['세어 보니, 세었더니'] 모두 [\d]{1,3}개").findall(df["질문"][i])
        b3=re.compile("[\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i])
        c1=[]#각 동물의 마리수
        c11=[] #모든 다리수
        c2=[] #동물의 다리수
        c22=[] #구하려는 동물의 다리수
        for j in range(0,len(b1)):
            d1=re.compile("[\d]{1,2}마리").findall(b1[j])
            d11=re.compile("[\d]{1,2}").findall(d1[0])
            c1.append(int(d11[0]))
            d2=re.compile("[\w]{1,4}").findall(b1[j])
            c2.append(r2[r1.index(d2[0])])
        d111=re.compile("[\d]{1,3}개").findall(b2)
        d1111=re.compile("[\d]{1,3}").findall(d111[0])
        c11.append(int(d1111))
        d22=re.compile("[\w]{1,4}").findall(b3)
        c22.append(r2[r1.index(d22[0])])
        print(i,c1,c2,c11,c22)
        qq=0
        for q in range(0,len(c1)):
            qq=qq+(c1[q]*c2[q])
        df['model_answer'][i]=((c11[0]-qq)//c22[0])


    elif  (re.compile("다리 수를 세어 보니 모두 [\d]{1,3}개").findall(df["질문"][i])) and ((re.compile("[\w]{1,3}가 모두 [\d]{1,3}마리라면").findall(df["질문"][i]))) and (re.compile("[\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i])):
        r1=['문어','강아지','오리','염소','닭','토끼','문어의','강아지의','오리의','염소의','닭의','토끼의']
        r2=[8,4,3,4,3,4,8,4,3,4,3,4]
        b1=re.compile("다리 수를 세어 보니 모두 [\d]{1,3}개").findall(df["질문"][i])
        b2=re.compile("[\w]{1,3}가 모두 [\d]{1,3}마리라면").findall(df["질문"][i])
        b3=re.compile("[\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i])
        c1=[]#각 동물의 마리수
        c11=[] #모든 다리수
        c2=[] #동물의 다리수
        c22=[] #구하려는 동물의 다리수
        for j in range(0,len(b2)):
            d1=re.compile("[\d]{1,2}마리").findall(b2[j])
            d11=re.compile("[\d]{1,2}").findall(d1[0])
            c1.append(int(d11[0]))
            d2=re.compile("[\w]{1,3}").findall(b2[j])
            c2.append(r2[r1.index(d2[0])])
        d111=re.compile("[\d]{1,3}개").findall(b1)
        d1111=re.compile("[\d]{1,3}").findall(d111[0])
        c11.append(int(d1111))
        d22=re.compile("[\w]{1,4}").findall(b3)
        c22.append(r2[r1.index(d22[0])])
        print(i,c1,c2,c11,c22)
        qq=0
        for q in range(0,len(c1)):
            qq=qq+(c1[q]*c2[q])
        df['model_answer'][i]=((c11[0]-qq)//c22[0])

    elif  (re.compile("다리 수를 세어 보니 모두 [\d]{1,3}개").findall(df["질문"][i])) and ((re.compile("[\w]{1,3}['는,은'] [\d]{1,3}마리라면").findall(df["질문"][i]))) and (re.compile("[\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i])):
        r1=['문어','강아지','오리','염소','닭','토끼','문어의','강아지의','오리의','염소의','닭의','토끼의']
        r2=[8,4,3,4,3,4,8,4,3,4,3,4]
        b1=re.compile("다리 수를 세어 보니 모두 [\d]{1,3}개").findall(df["질문"][i])
        b2=re.compile("[\w]{1,3}['는, 은'] [\d]{1,3}마리").findall(df["질문"][i])
        b3=re.compile("[\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i])
        c1=[]#각 동물의 마리수
        c11=[] #모든 다리수
        c2=[] #동물의 다리수
        c22=[] #구하려는 동물의 다리수
        for j in range(0,len(b2)):
            d1=re.compile("[\d]{1,2}마리").findall(b2[j])
            d11=re.compile("[\d]{1,2}").findall(d1[0])
            c1.append(int(d11[0]))
            d2=re.compile("[\w]{1,3}").findall(b2[j])
            c2.append(r2[r1.index(d2[0])])
        d111=re.compile("[\d]{1,3}개").findall(b1)
        d1111=re.compile("[\d]{1,3}").findall(d111[0])
        c11.append(int(d1111))
        d22=re.compile("[\w]{1,4}").findall(b3)
        c22.append(r2[r1.index(d22[0])])
        print(i,c1,c2,c11,c22)
        qq=0
        for q in range(0,len(c1)):
            qq=qq+(c1[q]*c2[q])
        df['model_answer'][i]=((c11[0]-qq)//c22[0])
        
    elif  (re.compile("다리 수를 세어 보니 모두 [\d]{1,3}개").findall(df["질문"][i])) and ((re.compile("[\w]{1,3}와 [\w]{1,3}가 [\d]{1,3}, [\d]{1,3}마리라면").findall(df["질문"][i]))) and (re.compile("[\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i])):
        r1=['문어','강아지','오리','염소','닭','토끼','문어의','강아지의','오리의','염소의','닭의','토끼의']
        r2=[8,4,3,4,3,4,8,4,3,4,3,4]
        b1=re.compile("다리 수를 세어 보니 모두 [\d]{1,3}개").findall(df["질문"][i])
        b2=re.compile("[\w]{1,3}와 [\w]{1,3}가 [\d]{1,3}, [\d]{1,3}마리라면").findall(df["질문"][i])
        b3=re.compile("[\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i])
        c1=[]#각 동물의 마리수
        c11=[] #모든 다리수
        c2=[] #동물의 다리수
        c22=[] #구하려는 동물의 다리수
        
        d1=re.compile("[\d]{1,2}").findall(b2)
        for o in range(0,len(d1)):
            c1.append(int(d1[o]))
        d2=re.compile("[\w]{1,3}").findall(b2)
        for o in range(0,len(d2)):
            c2.append(r2[r1.index(d2[o])])
            
        d111=re.compile("[\d]{1,3}개").findall(b1)
        d1111=re.compile("[\d]{1,3}").findall(d111[0])
        c11.append(int(d1111))
        d22=re.compile("[\w]{1,4}").findall(b3)
        c22.append(r2[r1.index(d22[0])])
        print(i,c1,c2,c11,c22)
        qq=0
        for q in range(0,len(c1)):
            qq=qq+(c1[q]*c2[q])
        df['model_answer'][i]=((c11[0]-qq)//c22[0])
        
        
        
print(df['질문'][40],df['model_answer'][40])
print(df['질문'][71],df['model_answer'][71])
print(df['질문'][74],df['model_answer'][74])
print(df['질문'][76],df['model_answer'][76])
print(df['질문'][85],df['model_answer'][85])
# Out:
# 45 [7] [8]
# 55 [6] [8]
# 바퀴가 4개인 자동차가 6대 있습니다. 자동차 바퀴의 수를 곱셈식으로 나타내어 보세요. 4의 □배 24
# 두발자전거 2대와 세발자전거 3대가 있습니다. 자전거의 바퀴는 모두 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.  13
# 오토바이 3대와 승용차 2대가 있습니다. 바퀴는 모두 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.  14
# 자동차 6대가 있습니다. 자동차의 바퀴 수는 모두 몇 개인지 곱셈식을 써 보세요.
#
# □×□=□  24
# 주차장에 바퀴가 4개인 승용차가 6대, 바퀴가 2개인 오토바이가 9대 있습니다. 승용차와 오토바이 중 어느 것의 바퀴가 몇 개 더 많습니까?  42

# %%
# df.columns
# df.head(20)

# %%
# df.drop(['kkma', 'okt'], axis=1)

# %%
# df.head(20)

# %%
df22=df.copy()
df22.head()
# Out:
#                                                   질문  \
# 0              곰 인형이 2개씩 6묶음 있습니다. 곰 인형은 모두 몇 개일까요?
# 1  연희네 모둠 학생들은 학급문고에 책을 1권 또는 2권씩 내기로 했습니다. 9명이 낸...
# 2  과일 가게에 복숭아가 8개씩 5묶음이 있고, 사과가 3개씩 9묶음이 있습니다. 과일...
# 3  책상 위에 색연필이 7자루씩 3묶음 있고, 사인펜이 4자루씩 8묶음 있습니다. 책상...
# 4  호진이는 4권씩 묶여 있는 연습장을 2묶음, 수연이는 호진이의 4배만큼 가지고 있습...
#
#                                수식풀이  \
# 0                          2×6=[12]
# 1    2×9=[18] ; 18-13=[5] ; 1×[5]=5
# 2  8×5=[40] ; 3×9=[27] ; 40+27=[67]
# 3  7×3=[21] ; 4×8=[32] ; 21+32=[53]
# 4    4×2=[8] ; 8×4=[32] ; 8+32=[40]
#
#                                           키워드                 키워드1 model  \
# 0                             2개씩 6묶음, 모두 몇 개              씩, 모두 몇
# 1      학생들, 1권 또는 2권씩, 9명, 13권, 1권 낸 학생, 몇 명                씩, 몇
# 2                    8개씩 5묶음, 3개씩 9묶음, 모두 몇 개           씩, 씩, 모두 몇
# 3                 7자루씩 3묶음, 4자루씩 8묶음, 모두 몇 자루           씩, 씩, 모두 몇
# 4  4권씩, 2묶음, 수연이는 호진이의 4배만큼, 호진이와 수연이, 모두 몇 권  씩, 는, 의, 만큼,  모두 몇
#
#   model_answer
# 0           12
# 1
# 2           67
# 3           53
# 4

# %%
# df22.to_excel("answer.xlsx",index=False)

# %%
# df22.head()

# %%
# for i in range(len(df)):
#     if df['model_answer'][i] :
#         print(df['질문'][i])

# %%
df.columns
# Out:
# Index(['질문', '수식풀이', '키워드', '키워드1', 'model', 'model_answer'], dtype='object')

# %%
df['answer'] = ''
for i in range(len(df)):
    a = re.split(r'[\;\ ]', df['수식풀이'][i])[-1]
    print(a)
    aa = re.findall('\[\d+\]', a)
    print(aa)
    df['answer'][i] = int(re.findall('\d+', str(aa))[0])
# Out:
# 2×6=[12]
# ['[12]']
# 1×[5]=5
# ['[5]']
# 40+27=[67]
# ['[67]']
# 21+32=[53]
# ['[53]']
# 8+32=[40]
# ['[40]']
# 70-42=[28]
# ['[28]']
# 86-(42+40)=[4]
# ['[4]']
# 35-24=[11]
# ['[11]']
# 1+21=[22]
# ['[22]']
# 9×[4]=36
# ['[4]']
# 4×[9]=36
# ['[9]']
# 3×[8]=24
# ['[8]']
# 20+12+16-18=[30]
# ['[30]']
# 24+16=[40]
# ['[40]']
# 24+12=[36]
# ['[36]']
# 42-35=[7]
# ['[7]']
# 4×5=[20]
# ['[20]']
# 5×6=[30]
# ['[30]']
# 6×7=[42]
# ['[42]']
# 4×[9]=36
# ['[9]']
# 8×[3]=24
# ['[3]']
# 5×7=[35]
# ['[35]']
# 8×5=[40]
# ['[40]']
# 15+28=[43]
# ['[43]']
# 24+14=[38]
# ['[38]']
# 6+6=[12]
# ['[12]']
# 28+4=[32]
# ['[32]']
# 3×[4]=12
# ['[4]']
# 1+21=[22]
# ['[22]']
# 37-35=[2]
# ['[2]']
# 30-[17]=13
# ['[17]']
# 1+21=[22]
# ['[22]']
# 9×8=[72]
# ['[72]']
# 48-36=[12]
# ['[12]']
# 91-82=[9]
# ['[9]']
# 40+36-18-23=[35]
# ['[35]']
# 10+15=[25]
# ['[25]']
# 30-10=[20]
# ['[20]']
# 25+12=[37]
# ['[37]']
# 5×[5]=25
# ['[5]']
# 4×6=[24]
# ['[24]']
# 2×8=[16]
# ['[16]']
# 18+2+5=[25]
# ['[25]']
# 27+24=[51]
# ['[51]']
# 4×5=[20]
# ['[20]']
# 8×7=[56]
# ['[56]']
# 5×7=[35]
# ['[35]']
# 0+2+6+15+8=[31]
# ['[31]']
# 3×5=[15]
# ['[15]']
# 4×7=[28]
# ['[28]']
# 18+36=[54]
# ['[54]']
# 48+24=[72]
# ['[72]']
# 42-25=[17]
# ['[17]']
# 6×[4]=24
# ['[4]']
# 4+20=[24]
# ['[24]']
# 8×6=[48]
# ['[48]']
# 9×8=[72]
# ['[72]']
# 8×7=[56]
# ['[56]']
# 63-27=[36]
# ['[36]']
# 2×7=[14]
# ['[14]']
# 5×8=[40]
# ['[40]']
# 3×5=[15]
# ['[15]']
# 6×8=[48]
# ['[48]']
# 4×4=[16]
# ['[16]']
# 7×9=[63]
# ['[63]']
# 8×5=[40]
# ['[40]']
# 1×6=[6]
# ['[6]']
# 0×5=[0]
# ['[0]']
# 7×6=[42]
# ['[42]']
# 6×8=[48]
# ['[48]']
# 32+35=[67]
# ['[67]']
# 4+9=[13]
# ['[13]']
# 36-24=[12]
# ['[12]']
# 8×9=[72]
# ['[72]']
# 6+8=[14]
# ['[14]']
# 5×3=[15]
# ['[15]']
# 4×6=[24]
# ['[24]']
# 8×7=[56]
# ['[56]']
# 0+2+9=[11]
# ['[11]']
# 4×7=[28]
# ['[28]']
# 5×[5]=25
# ['[5]']
# 3×3=[9]
# ['[9]']
# 5×5=[25]
# ['[25]']
# [18]>14
# ['[18]']
# 54-5=[49]
# ['[49]']
# 24-18=[6]
# ['[6]']
# 8×6=[48]
# ['[48]']
# 3×7=[21]
# ['[21]']
# 5×8=8×[5]
# ['[5]']
# 7×9=[63]
# ['[63]']
# 18-16=[2]
# ['[2]']
# 5×4=4×[5]
# ['[5]']
# 35-32=[3]
# ['[3]']
# 39-9=[30]
# ['[30]']
# 8×3=[24]
# ['[24]']
# 28-24=[4]
# ['[4]']
# 30+49=[79]
# ['[79]']
# (4+3)×3=[21]
# ['[21]']
# 42-21=[19]
# ['[19]']
# 6×5=[30]
# ['[30]']
# 7×4=[28]
# ['[28]']
# 6×5=[30]
# ['[30]']
# 7×3=[21]
# ['[21]']
# 28-25=[3]
# ['[3]']
# 4-3=[1]
# ['[1]']
# 7×4=[28]
# ['[28]']
# 8×2=[16]
# ['[16]']
# 20-18=[2]
# ['[2]']
# 6+33=[39]
# ['[39]']
# 4×4=[16]
# ['[16]']
# 40-32=[8]
# ['[8]']
# 45-6=[39]
# ['[39]']
# 36-35=[1]
# ['[1]']
# 8×5=[40]
# ['[40]']
# 3+9+36=[48]
# ['[48]']
# 21-20=[1]
# ['[1]']
# [42]>40
# ['[42]']
# 24<[36]
# ['[36]']
# 9+31+23=[63]
# ['[63]']
# 6+18+27=[51]
# ['[51]']

# %%
df.head()
# Out:
#                                                   질문  \
# 0              곰 인형이 2개씩 6묶음 있습니다. 곰 인형은 모두 몇 개일까요?
# 1  연희네 모둠 학생들은 학급문고에 책을 1권 또는 2권씩 내기로 했습니다. 9명이 낸...
# 2  과일 가게에 복숭아가 8개씩 5묶음이 있고, 사과가 3개씩 9묶음이 있습니다. 과일...
# 3  책상 위에 색연필이 7자루씩 3묶음 있고, 사인펜이 4자루씩 8묶음 있습니다. 책상...
# 4  호진이는 4권씩 묶여 있는 연습장을 2묶음, 수연이는 호진이의 4배만큼 가지고 있습...
#
#                                수식풀이  \
# 0                          2×6=[12]
# 1    2×9=[18] ; 18-13=[5] ; 1×[5]=5
# 2  8×5=[40] ; 3×9=[27] ; 40+27=[67]
# 3  7×3=[21] ; 4×8=[32] ; 21+32=[53]
# 4    4×2=[8] ; 8×4=[32] ; 8+32=[40]
#
#                                           키워드                 키워드1 model  \
# 0                             2개씩 6묶음, 모두 몇 개              씩, 모두 몇
# 1      학생들, 1권 또는 2권씩, 9명, 13권, 1권 낸 학생, 몇 명                씩, 몇
# 2                    8개씩 5묶음, 3개씩 9묶음, 모두 몇 개           씩, 씩, 모두 몇
# 3                 7자루씩 3묶음, 4자루씩 8묶음, 모두 몇 자루           씩, 씩, 모두 몇
# 4  4권씩, 2묶음, 수연이는 호진이의 4배만큼, 호진이와 수연이, 모두 몇 권  씩, 는, 의, 만큼,  모두 몇
#
#   model_answer answer
# 0           12     12
# 1                   5
# 2           67     67
# 3           53     53
# 4                  40

# %%
# df.to_excel("answer.xlsx",index=False)

# %% [markdown]
# ## 통합

# %%
# import pandas as pd
# import numpy as np
# import re

# %%
# 나눗셈까지 합친 파일
#다리 개수

# df=pd.read_excel("./data/math_func_q_k_k1.xlsx")
# df['model_answer']=''


for i in range(0,len(df)):
    a=re.compile("[\d]{1,4}").findall(df["질문"][i])
    if (re.compile("[\w]{1,4} [\d]{1,2}마리의 다리는 모두 몇 개").findall(df["질문"][i])):
        r1=['문어','강아지','오리','염소','닭','토끼','문어의','강아지의','오리의','염소의','닭의','토끼의']
        r2=[8,4,3,4,3,4,8,4,3,4,3,4]
        b=re.compile("[\w]{1,4} [\d]{1,2}마리의 다리는 모두 몇 개").findall(df["질문"][i])
        c1=[]
        c2=[]
        for j in range(0,len(b)):
            d1=re.compile("[\d]{1,2}마리의 다리").findall(b[j])
            d11=re.compile("[\d]{1,2}").findall(d1[0])
            c1.append(int(d11[0]))
            d2=re.compile("[\w]{1,4}").findall(b[j])
            c2.append(r2[r1.index(d2[0])])
        print(i,c1,c2)
        for q in range(0,len(c1)):
            df['model_answer'][i]=(c1[q]*c2[q])

    elif  (re.compile("[\w]{1,4}의 다리를 세어 보니 모두 [\d]{1,3}개").findall(df["질문"][i])) and ((re.compile(" [\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i]))):
        r1=['문어','강아지','오리','염소','닭','토끼','문어의','강아지의','오리의','염소의','닭의','토끼의']
        r2=[8,4,3,4,3,4,8,4,3,4,3,4]
        b=re.compile("[\w]{1,4}의 다리를 세어 보니 모두 [\d]{1,3}개").findall(df["질문"][i])
        c1=[]
        c2=[]
        for j in range(0,len(b)):
            d1=re.compile("[\d]{1,3}개").findall(b[j])
            d11=re.compile("[\d]{1,3}").findall(d1[0])
            c1.append(int(d11[0]))
            d2=re.compile("[\w]{1,4}").findall(b[j])
            c2.append(r2[r1.index(d2[0])])
        print(i,c1,c2)
        
        for q in range(0,len(c1)):
            df['model_answer'][i]=(c1[q]//c2[q])
            
    elif  (re.compile("[\w]{1,4} [\d]{1,2}마리").findall(df["질문"][i])) and ((re.compile("[\w]{1,3}와 [\w]{1,3}의 다리 [\w]{0,2}를 ['세어 보니, 세었더니'] 모두 [\d]{1,3}개").findall(df["질문"][i]))) and (re.compile("[\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i])):
        r1=['문어','강아지','오리','염소','닭','토끼','문어의','강아지의','오리의','염소의','닭의','토끼의']
        r2=[8,4,3,4,3,4,8,4,3,4,3,4]
        b1=re.compile("[\w]{1,4} [\d]{1,2}마리").findall(df["질문"][i])
        b2=re.compile("[\w]{1,4}와 [\w]{1,3}의 다리 [\w]{0,2}를 ['세어 보니, 세었더니'] 모두 [\d]{1,3}개").findall(df["질문"][i])
        b3=re.compile("[\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i])
        c1=[]#각 동물의 마리수
        c11=[] #모든 다리수
        c2=[] #동물의 다리수
        c22=[] #구하려는 동물의 다리수
        for j in range(0,len(b1)):
            d1=re.compile("[\d]{1,2}마리").findall(b1[j])
            d11=re.compile("[\d]{1,2}").findall(d1[0])
            c1.append(int(d11))
            d2=re.compile("[\w]{1,4}").findall(b1[j])
            c2.append(r2[r1.index(d2[0])])
        d111=re.compile("[\d]{1,3}개").findall(b2)
        d1111=re.compile("[\d]{1,3}").findall(d111[0])
        c11.append(int(d1111))
        d22=re.compile("[\w]{1,4}").findall(b3)
        c22.append(r2[r1.index(d22[0])])
        print(i,c1,c2,c11,c22)
        qq=0
        for q in range(0,len(c1)):
            qq=qq+(c1[q]*c2[q])
        df['model_answer'][i]=((c11[0]-qq)//c22[0])


    elif  (re.compile("다리 수를 세어 보니 모두 [\d]{1,3}개").findall(df["질문"][i])) and ((re.compile("[\w]{1,3}가 모두 [\d]{1,3}마리라면").findall(df["질문"][i]))) and (re.compile("[\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i])):
        r1=['문어가','강아지가','오리가','염소가','닭이','문어','강아지','오리','염소','닭','토끼','문어','강아지는','오리는','염소는','닭은','토끼는','문어의','강아지의','오리의','염소의','닭의','토끼의']
        r2=[8,4,3,4,3,4,8,4,3,4,3,4,8,4,3,4,3,4]
        b1=re.compile("다리 수를 세어 보니 모두 [\d]{1,3}개").findall(df["질문"][i])
        b2=re.compile("[\w]{1,3}가 모두 [\d]{1,3}마리라면").findall(df["질문"][i])
        b3=re.compile("[\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i])
        c1=[]#각 동물의 마리수
        c11=[] #모든 다리수
        c2=[] #동물의 다리수
        c22=[] #구하려는 동물의 다리수
        for j in range(0,len(b2)):
            d1=re.compile("[\d]{1,2}마리").findall(b2[j])
            d11=re.compile("[\d]{1,2}").findall(d1[0])
            c1.append(int(d11[0]))
            d2=re.compile("[\w]{1,3}").findall(b2[j])
            c2.append(r2[r1.index(d2[0])])
        d111=re.compile("[\d]{1,3}개").findall(b1[0])
        d1111=re.compile("[\d]{1,3}").findall(d111[0])
        c11.append(int(d1111[0]))
        d22=re.compile("[\w]{1,4}").findall(b3[0])
        c22.append(r2[r1.index(d22[0])])
        print(i,c1,c2,c11,c22)
        qq=0
        for q in range(0,len(c1)):
            qq=qq+(c1[q]*c2[q])
        df['model_answer'][i]=((c11[0]-qq)//c22[0])

    elif  (re.compile("다리 수를 세어 보니 모두 [\d]{1,3}개").findall(df["질문"][i])) and ((re.compile("[\w]{1,3}['는,은'] [\d]{1,3}마리라면").findall(df["질문"][i]))) and (re.compile("[\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i])):
        r1=['강아지는','오리는','염소는','닭은','토끼는','문어','강아지','오리','염소','닭','토끼','문어의','강아지의','오리의','염소의','닭의','토끼의']
        r2=[8,4,3,4,3,4,8,4,3,4,3,4,8,4,3,4,3,4]
        b1=re.compile("다리 수를 세어 보니 모두 [\d]{1,3}").findall(df["질문"][i])
        b2=re.compile("[\w]{1,3}['는, 은'] [\d]{1,3}마리").findall(df["질문"][i])
        b3=re.compile("[\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i])
        c1=[]#각 동물의 마리수
        c11=[] #모든 다리수
        c2=[] #동물의 다리수
        c22=[] #구하려는 동물의 다리수
        for j in range(0,len(b2)):
            d1=re.compile("[\d]{1,2}마리").findall(b2[j])
            d11=re.compile("[\d]{1,2}").findall(d1[0])
            c1.append(int(d11[0]))
            d2=re.compile("[\w]{1,3}").findall(b2[j])
            c2.append(r2[r1.index(d2[0])])
        d111=re.compile("[\d]{1,2}").findall(b1[0])
        c11.append(int(d111[0]))
        d22=re.compile("[\w]{1,4}").findall(b3[0])
        c22.append(r2[r1.index(d22[0])])
        print(i,c1,c2,c11,c22)
        qq=0
        for q in range(0,len(c1)):
            qq=qq+(c1[q]*c2[q])
        df['model_answer'][i]=((c11[0]-qq)//c22[0])
        
    elif  (re.compile("다리 수를 세어 보니 모두 [\d]{1,3}개").findall(df["질문"][i])) and ((re.compile("[\w]{1,3}와 [\w]{1,3}가 [\d]{1,3}, [\d]{1,3}마리라면").findall(df["질문"][i]))) and (re.compile("[\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i])):
        r1=['문어','강아지','오리','염소','닭','토끼','문어의','강아지의','오리의','염소의','닭의','토끼의']
        r2=[8,4,3,4,3,4,8,4,3,4,3,4,8,4,3,4,3,4]
        b1=re.compile("다리 수를 세어 보니 모두 [\d]{1,3}개").findall(df["질문"][i])
        b2=re.compile("[\w]{1,3}와 [\w]{1,3}가 [\d]{1,3}, [\d]{1,3}마리라면").findall(df["질문"][i])
        b3=re.compile("[\w]{1,4}['은, 는'] 몇 마리").findall(df["질문"][i])
        c1=[]#각 동물의 마리수
        c11=[] #모든 다리수
        c2=[] #동물의 다리수
        c22=[] #구하려는 동물의 다리수
        
        d1=re.compile("[\d]{1,2}").findall(b2)
        for o in range(0,len(d1)):
            c1.append(int(d1[o]))
        d2=re.compile("[\w]{1,3}").findall(b2)
        for o in range(0,len(d2)):
            c2.append(r2[r1.index(d2[o])])
            
        d111=re.compile("[\d]{1,3}개").findall(b1)
        d1111=re.compile("[\d]{1,3}").findall(d111[0])
        c11.append(int(d1111))
        d22=re.compile("[\w]{1,4}").findall(b3)
        c22.append(r2[r1.index(d22[0])])
        print(i,c1,c2,c11,c22)
        qq=0
        for q in range(0,len(c1)):
            qq=qq+(c1[q]*c2[q])
        df['model_answer'][i]=((c11[0]-qq)//c22[0])
# Out:
# 45 [7] [8]
# 55 [6] [8]

# %%
# df.columns

# %%
# df.head(20)

# %%
# df22=df.copy()
# df22.head()
#df=df22
#df.head()

# %%
# df=pd.read_excel("./data/math_func_q_k_k1.xlsx")
# df['model_answer']=''

for i in range(0,len(df)):
    if (re.compile("나이").findall(df["질문"][i])):print(i, df["질문"][i])
# Out:
# 81 지우 동생의 나이는 3살입니다. 지우의 나이는 동생의 나이의 3배입니다. 지우의 나이는 몇 살일까요?
# 93 성현이의 나이는 9살입니다. 어머니의 나이는 성현이의 나이의 4배보다 3살 더 많습니다. 어머니는 성현이보다 몇 살 더 많은지 풀이 과정을 쓰고, 답을 구하시오.
# 106 동생의 나이는 3살이고, 내 나이는 동생 나이의 2배보다 2살 더 많습니다. 오빠의 나이는 내 나이의 2배라면, 오빠는 몇 살입니까?
# 111 나현이는 9살입니다. 아버지의 나이는 나현이 나이의 5배보다 6살 더 적습니다. 아버지의 나이는 몇 살입니까?

# %%
#df=pd.read_excel("math_func_q_k_k1.xlsx")
#df['model_answer']=''

 
for i in range(0,len(df)):
    if (re.compile("[\w]{1,5}['의 나이는,는,은'] [\d]{1,2}살").findall(df["질문"][i])) and (re.compile("보다 몇 살 더 많을까요?").findall(df["질문"][i])):
        a1=re.compile("[\w]{1,5}['의 나이는,는,은'] [\d]{1,2}살").findall(df["질문"][i])
        a111=[]
        for j in range(0,len(a1)):
            a11=re.compile("[\d]{1,2}").findall(a1[j])
            a111.append(a11[0])
        if len(a111)==2:    
            df["model_answer"][i]=abs(int(a111[0])-int(a111[1]))
        
    elif (re.compile("의 나이를 더하면 [\d]{1,2}살").findall(df["질문"][i])) and (re.compile("의 나이가 [\d]{1,2}살이라면").findall(df["질문"][i])) and (re.compile("나이는 몇 살입니까").findall(df["질문"][i])):
        a1=re.compile("의 나이를 더하면 [\d]{1,2}살").findall(df["질문"][i])
        a111=[]
        for j in range(0,len(a1)):
            a11=re.compile("[\d]{1,2}").findall(a1[j])
            a111.append(a11[0])
        b1=re.compile("의 나이가 [\d]{1,2}살이라면").findall(df["질문"][i])
        b111=[]
        for j in range(0,len(b1)):
            b11=re.compile("[\d]{1,2}").findall(b1[j])
            b111.append(b11[0])
        df["model_answer"][i]=abs(int(a111[0])-int(b111[0]))
        
    
    elif (re.compile("[\w]{1,5}['의 나이는,는,은'] [\d]{1,2}살").findall(df["질문"][i])) and (re.compile("[\w]{1,5}의 나이는 [\w]{1,5}의 나이의 [\d]{1,2}배['라면,입니다']").findall(df["질문"][i])):
        a1=re.compile("[\w]{1,5}['의 나이는,는,은'] [\d]{1,2}살").findall(df["질문"][i])
        a111=[]
        for j in range(0,len(a1)):
            a11=re.compile("[\d]{1,2}").findall(a1[j])
            a111.append(a11[0])
        b1=re.compile("[\w]{1,5}의 나이는 [\w]{1,5}의 나이의 [\d]{1,2}배['라면,입니다']").findall(df["질문"][i])
        b111=[]
        for j in range(0,len(b1)):
            b11=re.compile("[\d]{1,2}").findall(b1[j])
            b111.append(b11[0])
        df["model_answer"][i]=(int(a111[0])*int(b111[0]))

        
for i in range(0,len(df)):
    if (re.compile("[\w]{1,5}['의 나이는,는,은'] [\d]{1,2}살").findall(df["질문"][i])) and (re.compile("[\w]{1,5}의 나이는 [\w]{1,5}의 나이의 [\d]{1,2}배보다 [\d]{1,2}살 더 많").findall(df["질문"][i])):
        a1=re.compile("[\w]{1,5}['의 나이는,는,은'] [\d]{1,2}살").findall(df["질문"][i])
        a111=[]
        for j in range(0,len(a1)):
            a11=re.compile("[\d]{1,2}").findall(a1[j])
            a111.append(a11[0])
        b1=re.compile("[\w]{1,5}의 나이는 [\w]{1,5}의 나이의 [\d]{1,2}배보다 [\d]{1,2}살 더 많").findall(df["질문"][i])
        b111=[]
        for j in range(0,len(b1)):
            b11=re.compile("[\d]{1,2}").findall(b1[j])
            b111.append(b11[0])
            b111.append(b11[1])
        if len(b111)==2:
            df["model_answer"][i]=(int(a111[0])*int(b111[0])+int(b111[1]))
        
    elif (re.compile("[\w]{1,5}['의 나이는,는,은'] [\d]{1,2}살").findall(df["질문"][i])) and (re.compile("[\w]{1,5}의 나이는 [\w]{1,5}의 나이의 [\d]{1,2}배보다 [\d]{1,2}살 더 ['많습니다,많다면']").findall(df["질문"][i])) and (re.compile("[\w]{1,5}의 나이는 [\w]{1,5}의 나이의 [\d]{1,2}배['라면,입니다']").findall(df["질문"][i])):
        a1=re.compile("[\w]{1,5}['의 나이는,는,은'] [\d]{1,2}살").findall(df["질문"][i])
        a111=[]
        for j in range(0,len(a1)):
            a11=re.compile("[\d]{1,2}").findall(a1[j])
            a111.append(a11[0])
        b1=re.compile("[\w]{1,5}의 나이는 [\w]{1,5}의 나이의 [\d]{1,2}배보다 [\d]{1,2}살 더 ['많습니다,많다면']").findall(df["질문"][i])
        b111=[]
        for j in range(0,len(b1)):
            b11=re.compile("[\d]{1,2}").findall(b1[j])
            b111.append(b11[0])
            b111.append(b11[1])
        c1=re.compile("[\w]{1,5}의 나이는 [\w]{1,5}의 나이의 [\d]{1,2}배['라면,입니다']").findall(df["질문"][i])
        c111=[]
        for j in range(0,len(c1)):
            c11=re.compile("[\d]{1,2}").findall(c1[j])
            c111.append(c11[0])
        df["model_answer"][i]=(int(a111[0])*int(b111[0])+int(b111[1]))*int(c111[0])
        
        
    elif (re.compile("['는,은'] [\d]{1,2}살").findall(df["질문"][i])) and (re.compile("[\w]{1,5}의 나이는 [\w]{1,5}의 나이의 [\d]{1,2}배보다 [\d]{1,2}살 더 적").findall(df["질문"][i])):
        a1=re.compile("['는,은'] [\d]{1,2}살").findall(df["질문"][i])
        a111=[]
        for j in range(0,len(a1)):
            a11=re.compile("[\d]{1,2}").findall(a1[j])
            a111.append(a11[0])
        b1=re.compile("[\w]{1,5}의 나이는 [\w]{1,5}의 나이의 [\d]{1,2}배보다 [\d]{1,2}살 더 적").findall(df["질문"][i])
        b111=[]
        for j in range(0,len(b1)):
            b11=re.compile("[\d]{1,2}").findall(b1[j])
            b111.append(b11[0])
            b111.append(b11[1])
        df["model_answer"][i]=(int(a111[0])*int(b111[0])-int(b111[1]))
        
    elif (re.compile("['는,은'] [\d]{1,2}살").findall(df["질문"][i])) and (re.compile("[\w]{1,5}의 나이는 [\w]{1,5}의 나이의 [\d]{1,2}배보다 [\d]{1,2}살 더 적").findall(df["질문"][i])) and (re.compile("[\w]{1,5}의 나이는 [\w]{1,5}의 나이의 [\d]{1,2}배['라면,입니다']").findall(df["질문"][i])):
        a1=re.compile("['는,은'] [\d]{1,2}살").findall(df["질문"][i])
        a111=[]
        for j in range(0,len(a1)):
            a11=re.compile("[\d]{1,2}").findall(a1[j])
            a111.append(a11[0])
        b1=re.compile("[\w]{1,5}의 나이는 [\w]{1,5}의 나이의 [\d]{1,2}배보다 [\d]{1,2}살 더 적").findall(df["질문"][i])
        b111=[]
        for j in range(0,len(b1)):
            b11=re.compile("[\d]{1,2}").findall(b1[j])
            b111.append(b11[0])
            b111.append(b11[1])
        c1=re.compile("[\w]{1,5}의 나이는 [\w]{1,5}의 나이의 [\d]{1,2}배['라면,입니다']").findall(df["질문"][i])
        c111=[]
        for j in range(0,len(c1)):
            c11=re.compile("[\d]{1,2}").findall(c1[j])
            c111.append(c11[0])
        df["model_answer"][i]=(int(a111[0])*int(b111[0])-int(b111[1]))*int(c111[0])

# %%
# www=[150,170,210,321,333,346,351]   
# for i in www:
#     print(df["질문"][i])
#     print(df['model_answer'][i])

# %%
for i in range(0,len(df)):
    if (re.compile("가위바위보").findall(df["질문"][i])):print(i,df["질문"][i])
# Out:
# 48 3명의 친구들이 가위바위보를 하여 모두 보를 냈습니다. 펼친 손가락은 모두 몇 개입니까?
# 54 6명의 어린이가 가위바위보를 했습니다. 그중 2명의 어린이가 가위를 내서 이겼을 때, 6명의 어린이가 펼친 손가락은 모두 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.

# %%
#가위바위보
for i in range(0,len(df)):  
    if (re.compile("펼친 손가락은 모두 몇 개").findall(df["질문"][i])): 
        r1=['가위','바위','보']
        r2=[2,0,5]
        #r3=['보','가위','바위']
        r4=[5,2,0]
        a=re.compile("[\d]{1,2}명의 [\w]{1,5}['이,가'] 가위바위보를").findall(df["질문"][i])
        a1=re.compile("[\d]{1,2}").findall(a[0])
        if (re.compile("모두 ['가위,바위,보']를").findall(df["질문"][i])) :
            b=re.compile("모두 ['가위,바위,보']를").findall(df["질문"][i])
            b1=re.compile("['가위,바위,보']").findall(b[0])
            df["model_answer"][i]=r2[r1.index(b1[0])]*int(a1[0])
        elif (re.compile("['가위,바위,보']를 내서 이겼을 때").findall(df["질문"][i])) :
            b=re.compile("[\w]{1,5} [\d]{1,2}명의").findall(df["질문"][i])
            bb=re.compile('[\w]{1,2}를 내서 이겼을 때').findall(df["질문"][i])
            b1=re.compile("[\w]{1,2}").findall(bb[0])
            b2=re.compile("[\d]{1,2}").findall(b[0])
            df["model_answer"][i]=r2[r1.index(b1[0])]*int(b2[0])+r4[r1.index(b1[0])]*(int(a1[0])-int(b2[0]))
            
#df["model_answer"][294]

# %%
for i in range(0,len(df)):
    if (re.compile("바르게 계산한 값").findall(df["질문"][i])):print(i,df["질문"][i])
# Out:
# 89 어떤 수에 9를 곱해야 할 것을 잘못하여 6을 곱했더니 42가 되었습니다. 바르게 계산한 값을 구하시오.

# %%
#잘못된 계산 바르게 계산한 값
for i in range(0,len(df)):
    r1=['더해야','빼야',"곱해야","나누어야","나눠야"]
    r2=['더했','뺐',"곱했","나눴","나누었"]
    if (re.compile("어떤 수에 [\d]{1,3}를 [\w]{2,3} 할 것을 잘못하여 [\d]{1,3}을 [\w]{1,3}더니 [\d]{1,5}").findall(df["질문"][i])):
        a=re.compile("어떤 수에 [\d]{1,5}를 [\w]{2,3} 할 것을 잘못하여 [\d]{1,5}을 [\w]{1,3}더니 [\d]{1,5}").findall(df["질문"][i])
        a1=re.compile("어떤 수에 [\d]{1,5}를 [\w]{2,3} 할 것을 잘못하여").findall(a[0])
        a11=re.compile("[\d]{1,5}").findall(a1[0])
        a11=int(a11[0])
        a12=re.compile("[\w]{2,3}").findall(a1[0])
        a2=re.compile("[\d]{1,5}을 [\w]{1,3}더니 [\d]{1,5}").findall(a[0])
        a21=re.compile("[\d]{1,5}").findall(a2[0])
        a211=int(a21[0])
        a212=int(a21[1])
        a22=re.compile("[\w]{2,3}").findall(a2[0])
        ans=[[(a212-a211)+a11,(a212-a211)-a11,(a212-a211)*a11,(a212-a211)/a11,(a212-a211)/a11],
             [(a212+a211)+a11,(a212+a211)-a11,(a212+a211)*a11,(a212+a211)/a11,(a212+a211)/a11],
             [(a212/a211)+a11,(a212/a211)-a11,(a212/a211)*a11,(a212/a211)/a11,(a212/a211)/a11],
             [(a212*a211)+a11,(a212*a211)-a11,(a212*a211)*a11,(a212*a211)/a11,(a212*a211)/a11]]
        for k1,k2 in zip(range(0,4),range(0,4)):
            df["model_answer"][i]=ans[k1][k2]

#df["model_answer"][329]

# %%
# df = df.drop(['kkma', 'okt', 'model','키워드'], axis=1)

# %%
# df.head(20)

# %%
# df.to_excel('answer_all.xlsx',index=False)

# %%
# df22.head(20)

# %% [markdown]
# **-슬기가 만든 모델로만 답 채운 파일 : answer_all.xlsx-**

# %% [markdown]
# ## 식

# %%
# df['식'] = ''

# for i in range(len(df)):              # 질문 읽기
#     a = re.split(r'[\.\,]',df['질문'][i])   # 문장 자르기
#     if ' ' in a:
#         a.remove(' ')
#     if ' 답을 구하시오' in a:
#         a.remove(' 답을 구하시오')
# #     print(a)
    
#     b = re.findall('[\d]{1,4}배',df['질문'][i])
#     c = re.findall('[\d]{1,4}대[\w]{0,4}', df['질문'][i])
# #     print(c)


#     for j in range(len(a)):                # 질문 하나에 나뉜 문장
#         sentence_okt = okt.morphs(a[0])      # 문장마다 형태소 자르기()
#         sentence_kkma = kkma.morphs(a[0])
#         a.append('(')
#         del a[0]
        
        
# #         if '바퀴' in sentence_kkma:
# #             if word == '대':
# #                 a.append('*')
        
#         for word in sentence_kkma: 
#             if kkma.pos(word)[0][1] == 'NR' and word != '몇' and word != '하나':
#                 a.append(word)
            
# #         for word in sentence_okt:
# #             if okt.pos(word)[0][1] == 'Number':
# #                 a.append(word)
#             elif word == '대':
#                 a.append('*')
#             elif word == '배'and b != []:
#                 a.append('*')
#             elif word == '씩':
#                 a.append('*')
#             elif word in ['모두', '더']:
#                 a.append('+')
#             elif word in ['나머지','부족','남']:
#                 a.append('-')
#             elif word == '주일':
#                 a.append('*')
#                 a.append('7')
#             elif word == '일주일':
#                 a.append('7')
#             elif word == '하나':
#                 a.append('1')
#             elif word == '두발':
#                 a.append('2')
#             elif word == '세발':
#                 a.append('3')
#             elif word in ['몇', '며칠']:
#                 a.append('X')
#         a.append(')')
# #     print(a)
# #     print(len(a))
#     result = ''
#     for k in range(len(a)):
#         result += a[k]
#         df['식'][i] = result

# %%
# df['식'].head()

# %%
# df.to_excel('answer_all.xlsx',index=False)

# %% [markdown]
# ## 곱셈 답 안나온거

# %%
# import pandas as pd
# import numpy as np
# import re
# df=pd.read_excel("./data/math_func_type.xlsx",sheet_name=2)
# df.head()

# %%
# import pandas as pd
# import numpy as np
# import re
# df=pd.read_excel("answer_all_present.xlsx")


# for i in range(len(df)):              # 질문 읽기
#     a = re.split(r'[\.\,]',df['질문'][i])   # 문장 자르기
#     if ' ' in a:
#         a.remove(' ')
#     if ' 답을 구하시오' in a:
#         a.remove(' 답을 구하시오')
# #     print(a)
#     b = re.compile('\d+').findall(df['질문'][i])
# #     print(b)
# #     print(len(b))     # 숫자 개수
#     c = re.compile('\의\ \d\배')
# #     print(c)
#     d = re.compile('\한\ ')
    
    
#     ###############  노랑 1
#     if d.findall(a[0]) != []  or '하나' in a[0] :
#         print(df['질문'][i])
#         if len(b) == 2:
#             print(df['질문'][i])
#             print(1*int(b[0])*int(b[1]))
#             df['model_answer'][i] = 1*int(b[0])*int(b[1])
#     if '하루' in a[0] and '일주일' in a[0] and len(b)==1:
#         print(df['질문'][i])
#         print(1*7*int(b[0]))
#         df['model_answer'][i] = 1*7*int(b[0])
#     ############ 주황 1       
#     if len(a) == 3 and len(b)==3 and a[0].count('씩')==1 and c.findall(a[1]) != [] and '몇' in a[2]:
#         print(df['질문'][i])
#         bb = int(b[0]) * int(b[1])
#         if re.findall('\w\와 \w', a[-1]):
#             print(bb + bb * int(b[2]))
#             df['model_answer'][i] = bb + bb * int(b[2])
#         else:
#             print(bb * int(b[2]))
#             df['model_answer'][i] = bb * int(b[2])
#     ############ 노랑 2
#     if len(b)==2 and len(c.findall(df['질문'][i])) == 1 and '더' not in df['질문'][i]:
#         print(df['질문'][i])
#         print(int(b[0])*int(b[1]))
#         df['model_answer'][i] = int(b[0])*int(b[1])
#     ########### 파랑
#     if  re.compile('묶으면| 묶는다면| 포장한다면| 담으면| 담으려고').search(df['질문'][i]):
#         print(df['질문'][i])
#         print(int(int(b[0])*int(b[1])/int(b[2])))
#         df['model_answer'][i] = int(int(b[0])*int(b[1])/int(b[2]))
#         if '더 필요합니까' in df['질문'][i]:
#             print(df['질문'][i])
#             print(int(int(b[0])*int(b[1])/int(b[2]))-int(b[1]))
#             df['model_answer'][i] = int(int(b[0])*int(b[1])/int(b[2]))-int(b[1])
#     ############### 초록 1,2
#     if re.compile('남은|남는|더 필요한지|남아').findall(df['질문'][i]): 
#         print(df['질문'][i])
#         if len(re.compile('\d+').findall(a[0]))==1 and '씩' in a[1] and len(b)==3:
#             print(df['질문'][i])
#             print(abs(int(b[0])-int(b[1])*int(b[2])))
#             df['model_answer'][i] = abs(int(b[0])-int(b[1])*int(b[2]))
#         if len(re.compile('\d+').findall(a[0]))==2 and '씩' in a[0] and len(b)==3:
#             if '중' in df['질문'][i] and df['질문'][i].count('개')==2:
#                 print(df['질문'][i])
#                 print(abs(int(b[0])*(int(b[1])-int(b[2]))))
#                 df['model_answer'][i] = abs(int(b[0])*(int(b[1])-int(b[2])))
#             else:
#                 print(df['질문'][i])
#                 print(abs(int(b[0])*int(b[1])-int(b[2])))
#                 df['model_answer'][i] = abs(int(b[0])*int(b[1])-int(b[2]))
#         if df['질문'][i].count('씩')==2:
#             print(df['질문'][i])
#             print(int(b[0])*int(b[1])+int(b[2])*int(b[3])-int(b[4])-int(b[5]))
#             df['model_answer'][i] = int(b[0])*int(b[1])+int(b[2])*int(b[3])-int(b[4])-int(b[5])
#     ################# 초록 3
#     if re.compile('더 많이| 더 많습니까| 큰| 더').findall(df['질문'][i]) and len(b)==4 and re.compile('누가|누구').findall(df['질문'][i]):
#         print(df['질문'][i])
#         if '몇' not in df['질문'][i]:
#             print(max(int(b[0])*int(b[1]), int(b[2])*int(b[3])))
#             df['model_answer'][i] = max(int(b[0])*int(b[1]), int(b[2])*int(b[3]))
#         else:
#             print(abs(int(b[0])*int(b[1])-int(b[2])*int(b[3])))
#             df['model_answer'][i] = abs(int(b[0])*int(b[1])-int(b[2])*int(b[3]))
#     ############## 초록 4    
#     if re.findall('\w\의 \d\배보다 \d\w \더', df['질문'][i]):
#         print(df['질문'][i])
#         if len(a)==3 and len(re.findall('\w\의 \d\배보다 \d\w \더', a[1]))==1:
# #             print(df['질문'][i])
#             if '더 많' in df['질문'][i]:
#                 bb = int(b[0])*int(b[1])+int(b[2])
#                 if '모두' in a[-1]:
#                     print(df['질문'][i])
#                     print(bb+int(b[0]))
#                     df['model_answer'][i] = bb+int(b[0])
#                 elif '더 많은지' in a[-1]:
#                     print(df['질문'][i])
#                     print(bb-int(b[0]))
#                     df['model_answer'][i] = bb-int(b[0])
#             if '더 적' in df['질문'][i]:
#                 print(df['질문'][i])
#                 print(int(b[0])*int(b[1])-int(b[2]))
#                 df['model_answer'][i] = int(b[0])*int(b[1])-int(b[2])
#         if len(a)==4 and len(re.findall('\w\의 \d\배보다 \d\w \더 많', a[1]))==1 and re.findall('\w의 \d배', a[2]):
#             print(df['질문'][i])
#             print((int(b[0])*int(b[1])+int(b[2]))*int(b[3]))
#             df['model_answer'][i] = (int(b[0])*int(b[1])+int(b[2]))*int(b[3])
#         if re.findall('\w\의 \d\배보다 \d\w \더 많', a[2]) and re.findall('\w보다 \d\w \더 적', a[3]) and '모두' in a[-1]:
#             print(df['질문'][i])
#             bb=int(b[0])+int(b[1])
#             cc=bb*int(b[2])+int(b[3])
#             print(bb+bb*int(b[2])+int(b[3])+cc-int(b[4]))
#             df['model_answer'][i] = bb+bb*int(b[2])+int(b[3])+cc-int(b[4])

# %%
df['model_answer'][1]
# Out:
# ''

# %% [markdown]
# ## 답 안나온 것 채우는 모델

# %%
import pandas as pd
import numpy as np
import re
df=pd.read_excel("answer_all.xlsx")


for i in range(len(df)):
    if df['model_answer'][i] != df['answer'][i]:
        a = re.split(r'[\.\,]',df['질문'][i])   # 문장 자르기
        if ' ' in a:
            a.remove(' ')
        if ' 답을 구하시오' in a:
            a.remove(' 답을 구하시오')
    #     print(a)
        b = re.compile('\d+').findall(df['질문'][i])
    #     print(b)
    #     print(len(b))     # 숫자 개수
        c = re.compile('\의\ \d\배')
    #     print(c)
        d = re.compile('\한\ ')
    
    
        ###############  노랑 1
        if d.findall(a[0]) != []  or '하나' in a[0] :
#             print(df['질문'][i])
            if len(b) == 2:
                print(df['질문'][i])
                print(1*int(b[0])*int(b[1]))
                df['model_answer'][i] = 1*int(b[0])*int(b[1])
            if len(b)==3 and '씩' in a[0] and '사람' in a[0] and '명' in a[1]:
                print(df['질문'][i])
                print(int(b[0])*int(b[1])*int(b[2]))
                df['model_answer'][i] = int(b[0])*int(b[1])*int(b[2])
        if '하루' in a[0] and '일주일' in a[0] and len(b)==1:
            print(df['질문'][i])
            print(1*7*int(b[0]))
            df['model_answer'][i] = 1*7*int(b[0])
        ############ 주황 1       
        if len(a) == 3 and len(b)==3 and df['질문'][i].count('씩')==1 and '몇' in df['질문'][i]:
#             print(df['질문'][i])
            if c.findall(a[1]) != []:
                bb = int(b[0]) * int(b[1])
                if re.findall('\w\와 \w', a[-1]):
                    print(df['질문'][i])
                    print(bb + bb * int(b[2]))
                    df['model_answer'][i] = bb + bb * int(b[2])
                else:
                    print(df['질문'][i])
                    print(bb * int(b[2]))
                    df['model_answer'][i] = bb * int(b[2])
            elif re.findall('각각|사람당',df['질문'][i]):
                print(df['질문'][i])
                print(int(b[0]) * int(b[1])* int(b[2]))
                df['model_answer'][i] = int(b[0]) * int(b[1])* int(b[2])
        if len(a)>=3 and len(b)==3 and len(c.findall(df['질문'][i]))==2 and '모두' in a[-1]:
            print(df['질문'][i])
            print(int(b[0])+int(b[0])*int(b[1])+int(b[0])*int(b[1])*int(b[2]))
            df['model_answer'][i] = int(b[0])+int(b[0])*int(b[1])+int(b[0])*int(b[1])*int(b[2])
        ############ 노랑 2
        if len(b)==2 and len(c.findall(df['질문'][i])) == 1 and '더' not in df['질문'][i]:
            print(df['질문'][i])
            print(int(b[0])*int(b[1]))
            df['model_answer'][i] = int(b[0])*int(b[1])
        elif '열리지 않은' in df['질문'][i]:
            print(df['질문'][i])
            df['model_answer'][i] = 0*int(b[0])
        ########### 파랑
        if  re.compile('묶으면| 묶는다면| 포장한다면| 담으면| 담으려고|몇 묶음과 같습니까|같은 양|담는다면').search(df['질문'][i]):
            print(df['질문'][i])
            print(int(int(b[0])*int(b[1])/int(b[2])))
            df['model_answer'][i] = int(int(b[0])*int(b[1])/int(b[2]))
            if '더 필요합니까' in df['질문'][i]:
                print(df['질문'][i])
                print(int(int(b[0])*int(b[1])/int(b[2]))-int(b[1]))
                df['model_answer'][i] = int(int(b[0])*int(b[1])/int(b[2]))-int(b[1])
            if df['질문'][i].count('씩')==4 :
                print(df['질문'][i])
                print(int(int(b[0])*int(b[1])/int(b[4])+int(b[2])*int(b[3])/int(b[5])))
                df['model_answer'][i] = int(int(b[0])*int(b[1])/int(b[4])+int(b[2])*int(b[3])/int(b[5]))
        ############### 초록 1,2
        if re.compile('남은|남는|\몇\ \w \필요|\더\ \필요|남아|부족').findall(df['질문'][i]) and '담으려고' not in df['질문'][i]: 
#             print(df['질문'][i])
            if len(re.compile('\d+').findall(a[0]))==1 and '씩' in a[1] and len(b)==3:
                print(df['질문'][i])
                print(abs(int(b[0])-int(b[1])*int(b[2])))
                df['model_answer'][i] = abs(int(b[0])-int(b[1])*int(b[2]))
            if len(re.compile('\d+').findall(a[0]))==2 and '씩' in a[0] and len(b)==3:
                if '중' in df['질문'][i] and df['질문'][i].count('개')==2:
                    print(df['질문'][i])
                    print(abs(int(b[0])*(int(b[1])-int(b[2]))))
                    df['model_answer'][i] = abs(int(b[0])*(int(b[1])-int(b[2])))
                else:
                    print(df['질문'][i])
                    print(abs(int(b[0])*int(b[1])-int(b[2])))
                    df['model_answer'][i] = abs(int(b[0])*int(b[1])-int(b[2]))
            if df['질문'][i].count('씩')==2 and len(a)==2:
                
                print(df['질문'][i])
                print(abs(int(b[0])*int(b[1])+int(b[2])*int(b[3])-int(b[4])-int(b[5])))
                df['model_answer'][i] = abs(int(b[0])*int(b[1])+int(b[2])*int(b[3])-int(b[4])-int(b[5]))
            elif '씩' in a[0] and '씩' in a[1] and '1명씩' in df['질문'][i]:    
                
                print(df['질문'][i])
                print(abs(int(b[0])*int(b[1])+int(b[2])*int(b[3])-int(b[4])))
                df['model_answer'][i] = abs(int(b[0])*int(b[1])+int(b[2])*int(b[3])-int(b[4]))
        ################# 초록 3
        if re.compile('더 많이| 더 많습니까| 큰| 더').findall(df['질문'][i]): 
#             print(df['질문'][i])
            if len(b)==4 and re.compile('누가|누구').findall(df['질문'][i]):
#                 print(df['질문'][i])
                if '몇' not in df['질문'][i]:
                    print(max(int(b[0])*int(b[1]), int(b[2])*int(b[3])))
                    df['model_answer'][i] = max(int(b[0])*int(b[1]), int(b[2])*int(b[3]))
                else:
                    print(abs(int(b[0])*int(b[1])-int(b[2])*int(b[3])))
                    df['model_answer'][i] = abs(int(b[0])*int(b[1])-int(b[2])*int(b[3]))
                    
            if '씩' in df['질문'][i] and re.findall('\d\의\ \d배', df['질문'][i]):
                print(df['질문'][i])
                print(abs(int(b[0])*int(b[1])-int(b[2])*int(b[3])))
                df['model_answer'][i] = abs(int(b[0])*int(b[1])-int(b[2])*int(b[3]))
        ############## 초록 4    
        if re.findall('\w\의 \d\배보다 \d\w \더', df['질문'][i]):
            print(df['질문'][i])
            if len(a)==3 and len(re.findall('\w\의 \d\배보다 \d\w \더', a[1]))==1:
    #             print(df['질문'][i])
                if '더 많' in df['질문'][i]:
                    bb = int(b[0])*int(b[1])+int(b[2])
                    if '모두' in a[-1]:
                        print(df['질문'][i])
                        print(bb+int(b[0]))
                        df['model_answer'][i] = bb+int(b[0])
                    elif '더 많은지' in a[-1]:
                        print(df['질문'][i])
                        print(bb-int(b[0]))
                        df['model_answer'][i] = bb-int(b[0])
                if '더 적' in df['질문'][i]:
                    print(df['질문'][i])
                    print(int(b[0])*int(b[1])-int(b[2]))
                    df['model_answer'][i] = int(b[0])*int(b[1])-int(b[2])
            if len(a)==4 and len(re.findall('\w\의 \d\배보다 \d\w \더 많', a[1]))==1 and re.findall('\w의 \d배', a[2]):
                print(df['질문'][i])
                print((int(b[0])*int(b[1])+int(b[2]))*int(b[3]))
                df['model_answer'][i] = (int(b[0])*int(b[1])+int(b[2]))*int(b[3])
            if re.findall('\w\의 \d\배보다 \d\w \더 많', a[2]) and re.findall('\w보다 \d\w \더 적', a[3]) and '모두' in a[-1]:
                print(df['질문'][i])
                bb=int(b[0])+int(b[1])
                cc=bb*int(b[2])+int(b[3])
                print(bb+bb*int(b[2])+int(b[3])+cc-int(b[4]))
                df['model_answer'][i] = bb+bb*int(b[2])+int(b[3])+cc-int(b[4])
# Out:
# 호진이는 4권씩 묶여 있는 연습장을 2묶음, 수연이는 호진이의 4배만큼 가지고 있습니다. 호진이와 수연이가 가지고 있는 연습장은 모두 몇 권인지 구하시오.
# 40
# 연필이 70자루 있습니다. 이 연필을 7자루씩 6명에게 나누어 주었습니다. 남은 연필은 몇 자루인지 풀이 과정을 쓰고, 답을 구하시오.
# 28
# 운동장에 6명씩 앉을 수 있는 긴 의자가 7개, 5명씩 앉을 수 있는 긴 의자가 8개 있습니다. 학생 86명이 모두 긴 의자에 앉으려고 하니 의자가 부족해 나머지 학생들은 1명씩 앉을 수 있는 의자에 앉으려고 합니다. 1명씩 앉는 의자는 몇 개 필요합니까?
# 4
# 사탕이 모두 35개 있었습니다. 그 중에서 4개씩 6봉지를 만들어 친구에게 주었습니다. 남은 사탕은 몇 개입니까?
# 11
# 사탕이 6개씩 6묶음 있습니다. 이것을 9개씩 묶으면 몇 묶음이 됩니까?
# 4
# 사탕이 6개씩 6묶음 있습니다. 이것을 4개씩 묶으면 몇 묶음인지 구하시오.
# 9
# 딱지가 6장씩 4묶음 있습니다. 이 딱지를 3장씩 묶는다면, 모두 몇 묶음이 됩니까?
# 8
# 책을 5권씩 넣어 포장할 수 있는 상자가 7개 있습니다. 같은 책을 42권 포장하려고 할 때, 포장하고 남는 책은 몇 권입니까?
# 7
# 사탕이 4개씩 6묶음이 있습니다. 이 사탕을 8개씩 묶는다면 모두 몇 묶음이 됩니까?
# 3
# 어머니께서 귤을 9개씩 4봉지, 사과를 8개씩3봉지 사셨습니다. 한 접시에 귤은 6개씩, 사과는 4개씩 담는다면, 접시는 모두 몇 개가 필요합니까? (단, 귤과 사과를 따로 담습니다.)
# 4
# 어머니께서 귤을 9개씩 4봉지, 사과를 8개씩3봉지 사셨습니다. 한 접시에 귤은 6개씩, 사과는 4개씩 담는다면, 접시는 모두 몇 개가 필요합니까? (단, 귤과 사과를 따로 담습니다.)
# 12
# 사탕을 2개씩 6봉지로 포장하였습니다. 이 사탕을 다시 3개씩 포장한다면, 몇 봉지가 됩니까?
# 4
# 군밤이 6개씩 들어 있는 봉지가 5봉지 있습니다. 이 중 몇 개를 먹고 남은 것이 13개라면, 먹은 군밤은 몇 개 입니까?
# 17
# 문구점에 빨간색 색연필은 5자루씩 8통 있고 파란색 색연필은 9자루씩 4통 있습니다. 이 중에서 빨간색 색연필 18자루와 파란색 색연필 23자루를 팔았다면 남은 색연필은 몇 자루입니까?
# 35
# 영미는 생일잔치에 친구 5명을 초대했습니다. 초대한 친구들에게 각각 사탕 2개와 과자 3개씩을 주었습니다. 영미가 친구들에게 준 사탕과 과자는 모두 몇 개입니까?
# 30
# 빵이 5개씩 들어 있는 봉지가 6봉지 있습니다. 그 중에서 2봉지를 먹었습니다. 남아 있는 빵은 모두 몇 개입니까?
# 20
# 진경이가 한 상자의 높이를 뼘으로 재었더니 4뼘이었습니다. 7상자의 높이는 진경이의 뼘으로 모두 몇 뼘인지 풀이 과정을 쓰고, 답을 구하시오.
# 28
# 수지는 사탕 25개를 가지고 있습니다. 한 상자에 사탕을 6개씩 담아 모두 7상자를 만들려면 사탕은 몇 개가 더 필요한지 풀이 과정을 쓰고, 답을 구하시오.
# 17
# 빵이 한 봉지에 8개씩 3봉지 있습니다. 이 빵을 모두 꺼내어 다시 한 봉지에 6개씩 담으면 몇 봉지가 되는지 풀이 과정을 쓰고, 답을 구하시오.
# 4
# 인영이의 친구들이 한 사람당 딱지를  3장씩 3묶음 가지고 있습니다. 8명의 친구들이 가지고 있는 딱지는 모두 몇 장인지 풀이 과정을 쓰고, 답을 구하시오.
# 72
# 울타리 하나에 기둥이 8개 있습니다. 울타리 7개를 이어 오리 집을 만들었습니다. 기둥은 모두 몇 개입니까?
# 56
# 참외가 한 접시에 9개씩 7접시 있었습니다. 그중에서 3접시를 먹었다면 남은 참외는 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.
# 36
# 농구는 5명의 선수가 한 팀이 되어 경기를 합니다. 8팀의 선수는 모두 몇 명인지 풀이 과정을 쓰고, 답을 구하시오.
# 40
# 지우개 한 개의 길이는 3cm입니다. 지우개 5개의 길이는 몇 cm입니까?
# 15
# 한 장의 길이가 4cm인 색 테이프 4장을 그림과 같이 겹치지 않게 이어 붙였습니다. 이어 붙인 색 테이프의 전체 길이는 몇 cm인지 풀이 과정을 쓰고, 답을 구하시오.
# 16
# 사과가 열리지 않은 사과나무가 5그루 있습니다. 이 사과나무에 열린 사과는 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.
# 회전 그네를 한 번 운행할 때 6명씩 탈 수 있습니다. 8번 운행하면 몇 명까지 탈 수 있는지 곱셈식을 이용하여 구하시오.
# 48
# 한 통에 4개씩 들어 있는 껌이 9통 있습니다. 이 중에서 3통을 친구들에게 나누어 주었다면 남은 껌은 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.
# 24
# 재호는 하루에 4시간씩 일주일 동안 공부를 했습니다. 재호가 공부한 시간은 모두 몇 시간입니까?
# 28
# 성윤이와 지은이의 대화를 읽고 지은이가 쌓은 모형은 모두 몇 개인지 풀이 과정을 쓰고, 답을 구하시오.
# 성윤 : 모형 5개를 쌓았어.
# 지은 : 나는 네가 쌓은 모형 수의 5배만큼 쌓았어.
# 25
# 18
# 색연필을 지후는 8자루 가지고 있고 유민이는 지후의 6배만큼 가지고 있습니다. 유민이가 가지고 있는 색연필은 몇 자루입니까?
# 48
# 사과 5개씩 8묶음은 사과 8개씩 몇 묶음과 같습니까?
# 5
# 민서는 문제집을 하루에 5쪽씩 4일 동안 풀었습니다. 민서와 같은 양을 소희는 하루에 4쪽씩 푼다면 며칠 동안 풀어야 합니까?
# 5
# 성현이의 나이는 9살입니다. 어머니의 나이는 성현이의 나이의 4배보다 3살 더 많습니다. 어머니는 성현이보다 몇 살 더 많은지 풀이 과정을 쓰고, 답을 구하시오.
# 성현이의 나이는 9살입니다. 어머니의 나이는 성현이의 나이의 4배보다 3살 더 많습니다. 어머니는 성현이보다 몇 살 더 많은지 풀이 과정을 쓰고, 답을 구하시오.
# 30
# 사과는 8개 있고 참외는 사과의 3배만큼 있습니다. 참외는 모두 몇 개인지 덧셈식을 쓰고 답을 구하시오.
# 24
# 4
# 서연이와 민경이 중에서 스티커를 누가 몇 장 더 많이 가지고 있습니까?
#
# 서연 : 난 스티커를 4의 7배만큼 가지고 있어.
#
# 민경 : 난 스티커를 8장씩 3묶음을 가지고 있어.
# 4
# 송이네 집에는 2개의 꽃병에 꽃이 3송이씩 꽂혀 있습니다. 교실에 있는 꽃은 송이네 집 꽃의 5배입니다. 교실에 있는 꽃은 모두 몇 송이입니까?
# 30
# 영호는 구슬 7개를 가지고 있습니다. 기철이가 가지고 있는 구슬의 수는 영호가 가지고 있는 구슬의 수의 4배입니다. 기철이가 가지고 있는 구슬은 모두 몇 개입니까?
# 28
# 정은이는 엽서를 3장씩 2묶음 가지고 있습니다. 정은이의 언니는 정은이가 가지고 있는 엽서의 5배를 가지고 있습니다. 정은이 언니가 가지고 있는 엽서는 몇 장입니까?
# 30
# 현우는 딱지를 7장 가지고 있습니다. 규진이는 딱지를 현우의 3배만큼 가지고 있습니다. 규진이가 가지고 있는 딱지는 모두 몇 장입니까?
# 21
# 3
# 떡이 8개씩 3접시 있습니다. 이 떡을 다시 한 접시에 6개씩 담으려고 합니다. 접시가 처음보다 몇 개 더 필요합니까?
# 4
# 떡이 8개씩 3접시 있습니다. 이 떡을 다시 한 접시에 6개씩 담으려고 합니다. 접시가 처음보다 몇 개 더 필요합니까?
# 1
# 은주는 구슬을 7개 가지고 있습니다. 오빠가 가진 구슬은 은주가 가진 구슬의 4배입니다. 오빠가 가진 구슬은 몇 개입니까?
# 28
# 동생의 나이는 3살이고, 내 나이는 동생 나이의 2배보다 2살 더 많습니다. 오빠의 나이는 내 나이의 2배라면, 오빠는 몇 살입니까?
# 동생의 나이는 3살이고, 내 나이는 동생 나이의 2배보다 2살 더 많습니다. 오빠의 나이는 내 나이의 2배라면, 오빠는 몇 살입니까?
# 16
# 2
# 연아는 색종이를 6장 가지고 있습니다. 동생은 연아의 4배보다 9장 더 많이 가지고 있다면, 두 사람이 가지고 있는 색종이는 모두 몇 장입니까?
# 연아는 색종이를 6장 가지고 있습니다. 동생은 연아의 4배보다 9장 더 많이 가지고 있다면, 두 사람이 가지고 있는 색종이는 모두 몇 장입니까?
# 39
# 인혜는 구슬을 4개 가지고 있습니다. 재훈이는 구슬을 인혜의 4배만큼 가지고 있습니다. 재훈이가 가지고 있는 구슬은 모두 몇 개입니까?
# 16
# 8씩 5묶음은 8의 4배보다 몇 큰 수인지 풀이 과정을 쓰고 답을 구하세요.
# 8
# 나현이는 9살입니다. 아버지의 나이는 나현이 나이의 5배보다 6살 더 적습니다. 아버지의 나이는 몇 살입니까?
# 나현이는 9살입니다. 아버지의 나이는 나현이 나이의 5배보다 6살 더 적습니다. 아버지의 나이는 몇 살입니까?
# 39
# 36
# 승애는 색종이를 4장씩 2묶음 가지고 있고, 택림이는 승애가 가지고 있는 색종이의 5배를 가지고 있습니다. 택림이가 가지고 있는 색종이는 모두 몇 장입니까?
# 40
# 밭에서 호박, 오이, 고추를 따 왔습니다. 따 온 호박은 3개이고, 오이는 호박의 3배만큼, 고추는 오이의 4배만큼 따 왔습니다. 밭에서 따온 호박, 오이, 고추는 모두 몇 개입니까?
# 48
# 1
# 42
# 36
# 희진이는 파란 구슬 3개, 노란 구슬 6개를 가지고 있습니다. 민경이는 희진이가 가지고 있는 구슬의 3배보다 4개 더 많이 가지고 있고, 현주는 민경이가 가지고 있는 구슬의 개수보다 8개 더 적게 가지고 있습니다. 세 사람이 가지고 있는 구슬의 수는 모두 몇 개입니까?
# 희진이는 파란 구슬 3개, 노란 구슬 6개를 가지고 있습니다. 민경이는 희진이가 가지고 있는 구슬의 3배보다 4개 더 많이 가지고 있고, 현주는 민경이가 가지고 있는 구슬의 개수보다 8개 더 적게 가지고 있습니다. 세 사람이 가지고 있는 구슬의 수는 모두 몇 개입니까?
# 63
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.to_excel('answer_all_final_3.xlsx',index=False)
