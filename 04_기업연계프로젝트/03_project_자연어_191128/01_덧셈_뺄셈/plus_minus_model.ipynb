# %%
import pandas as pd

df=pd.read_csv("../data/plus_minus1.csv")
df.head()
# Out:
#                                                   질문  \
# 0  준기는 동화책을 어제는 58쪽，오늘은 54쪽 읽었습니다. 준기는 어제와 오늘 동화책...
# 1  곤충관에서는 곤충에게 먹이를 아침에 47봉지，점심에 69봉지를 주었습니다. 아침과 ...
# 2  나무 아래에 기린이 7마리 있습니다. 5마리가 더 온다면 모두 몇 마리인지 덧셈식을...
# 3  연수는 지금까지 훌라후프 8개를 뛰어넘었습니다. 연수가 6개를 더 뛰어넘으면 모두 ...
# 4  아름이는 사탕 15개를 가진 다운이보다 사탕이 13개 더 많습니다. 아름이가 가진 ...
#
#                              키워드                  키워드1
# 0             58쪽, 54쪽, 모두, 몇 쪽                모두, 몇
# 1    47봉지, 69봉지, 주었습니다, 모두, 몇 봉지          주었습니다, 모두, 몇
# 2          7마리, 5마리, 더 온다면, 몇 마리             더 온다면, 몇
# 3              8개, 6개, 더 모두, 몇 개              더 모두, 몇
# 4  15개, 보다, 13개, 더 많습니다, 가진, 몇 개   보다,  더 많습니다, 가진, 몇

# %%
import platform

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# sns.set()

from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:
    print("It's unknown system. Hangul fonts are not supported!")
    
# plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["figure.figsize"] = [12,6]

# %matplotlib inline

# %%
df.tail()
# Out:
#                                                     질문  \
# 235  철수는 사과 38개를 가지고 있습니다. 철수는 영희에게 사과 몇 개를 줬습니다. 철...
# 236  아름이는 사탕 8개를 가졌습니다. 몇 개를 다운이에게 주었더니 3개가 남았습니다. ...
# 237  민지는 색종이 12장을 가지고 있었는데, 몇 장을 사용하였더니 9장이 남았습니다. ...
# 238  주차장에 있던 자동차 5대 중 몇 대가 나가서 3대가 남았습니다. 주차장에서 나간 ...
# 239  준기는 연필 10자루를 가지고 있습니다. 동생에게 몇 자루를 주었더니 6자루가 남았...
#
#                                         키워드                      키워드1
# 235   38개, 가지고, 몇 개, 줬습니다., 지금, 25개, 몇 개, 준             몇, 줬습니다, 몇, 준
# 236       8개, 몇 개, 주었더니, 3개, 남았습니다., 준, 몇 개     몇, 주었더니, 남았습니다, 준, 몇
# 237  12장, 몇 장, 사용하였더니, 9장, 남았습니다., 사용한, 몇 장  몇, 사용하였더니, 남았습니다, 사용한, 몇
# 238    5대, 중, 몇 대, 나가서, 3대, 남았습니다., 나간, 몇 대  중, 몇 , 나가서, 남았습니다, 나간, 몇
# 239           10자루, 몇 자루, 주었더니, 6자루, 남았습니다.            몇, 주었더니, 남았습니다

# %%
from konlpy.tag import Kkma
kkma = Kkma()

from konlpy.tag import Okt
okt = Okt()


df["kkma"] = ''
df["okt"] = ''


for i in range(0, len(df)):
    #df['kkma'][i] = kkma.morphs(df["질문"][i])
    #df['okt'][i] = okt.morphs(df["질문"][i])
    df['kkma'][i] = kkma.pos(df["질문"][i])
    df['okt'][i] = okt.pos(df["질문"][i])
    
df.head()
# Out:
#                                                   질문  \
# 0  준기는 동화책을 어제는 58쪽，오늘은 54쪽 읽었습니다. 준기는 어제와 오늘 동화책...
# 1  곤충관에서는 곤충에게 먹이를 아침에 47봉지，점심에 69봉지를 주었습니다. 아침과 ...
# 2  나무 아래에 기린이 7마리 있습니다. 5마리가 더 온다면 모두 몇 마리인지 덧셈식을...
# 3  연수는 지금까지 훌라후프 8개를 뛰어넘었습니다. 연수가 6개를 더 뛰어넘으면 모두 ...
# 4  아름이는 사탕 15개를 가진 다운이보다 사탕이 13개 더 많습니다. 아름이가 가진 ...
#
#                              키워드                  키워드1  \
# 0             58쪽, 54쪽, 모두, 몇 쪽                모두, 몇
# 1    47봉지, 69봉지, 주었습니다, 모두, 몇 봉지          주었습니다, 모두, 몇
# 2          7마리, 5마리, 더 온다면, 몇 마리             더 온다면, 몇
# 3              8개, 6개, 더 모두, 몇 개              더 모두, 몇
# 4  15개, 보다, 13개, 더 많습니다, 가진, 몇 개   보다,  더 많습니다, 가진, 몇
#
#                                                 kkma  \
# 0  [(주, VV), (ㄴ, ETD), (길, VA), (는, ETD), (동화책, N...
# 1  [(곤충, NNG), (관, NNG), (에서, JKM), (는, JX), (곤충,...
# 2  [(나무, NNG), (아래, NNG), (에, JKM), (기린, NNG), (이...
# 3  [(연수, NNG), (는, JX), (지금, NNG), (까지, JX), (훌라후...
# 4  [(아름, NNP), (이, JKS), (늘, VV), (ㄴ, ETD), (사탕, ...
#
#                                                  okt
# 0  [(준, Noun), (기는, Verb), (동화책, Noun), (을, Josa)...
# 1  [(곤충관, Noun), (에서는, Josa), (곤충, Noun), (에게, Jo...
# 2  [(나무, Noun), (아래, Noun), (에, Josa), (기린, Noun)...
# 3  [(연수, Noun), (는, Josa), (지금, Noun), (까지, Josa)...
# 4  [(아름이, Noun), (는, Josa), (사탕, Noun), (15, Numb...

# %%
import re

df["model"]=''
df["model_answer"]=''

for i in range(0,len(df)):
    if re.compile("보다 [\w]{1,9} ['더 가지고 있습니다, 더 가지고 있습니까, 더 많이 가지고 있는지, 더 팔았습니까, 더 많았다고 합니다, 더 많습니까, 더 많은지, 더 많을까요, 더 많이 먹었습니까, 더 적게']").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        if int(a[0])<int(a[1]):
            df["model"][i]=[int(a[1]),"-",int(a[0])]
            df["model_answer"][i]=(int(a[1])-int(a[0]))
        elif int(a[0])>int(a[1]):
            df["model"][i]=[int(a[0]),'-',int(a[1])]
            df["model_answer"][i]=((int(a[0])-int(a[1])))
            
            
for i in range(0,len(df)):
    if re.compile("[\w]{1,9} ['더 많이 가지고 있는지,더 붙일 수 있습니까']").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        if int(a[0])<int(a[1]):
            df["model"][i]=[int(a[1]),"-",int(a[0])]
            df["model_answer"][i]=(int(a[1])-int(a[0]))
        elif int(a[0])>int(a[1]):
            df["model"][i]=[int(a[0]),'-',int(a[1])]
            df["model_answer"][i]=((int(a[0])-int(a[1])))
            
            
            
for i in range(0,len(df)):
    if re.compile("몇  [\w]{1,4}를 ['주었습니다. , 주었더니 ,줬습니다']").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        if int(a[0])<int(a[1]):
            df["model"][i]=[int(a[1]),"-",int(a[0])]
            df["model_answer"][i]=(int(a[1])-int(a[0]))
        elif int(a[0])>int(a[1]):
            df["model"][i]=[int(a[0]),'-',int(a[1])]
            df["model_answer"][i]=((int(a[0])-int(a[1])))
            
            
            
for i in range(0,len(df)):
    if re.compile("몇  [\w]{1,4}를 ['주었습니다. , 주었더니 ,줬습니다']").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        if int(a[0])<int(a[1]):
            df["model"][i]=[int(a[1]),"-",int(a[0])]
            df["model_answer"][i]=(int(a[1])-int(a[0]))
        elif int(a[0])>int(a[1]):
            df["model"][i]=[int(a[0]),'-',int(a[1])]
            df["model_answer"][i]=((int(a[0])-int(a[1])))
            
            
for i in range(0,len(df)):
    if re.compile("나누어").findall(df["질문"][i])!=[]:
        if re.compile("['를 가졌다면, 를 주었다면, 먼저,  를 쥐었다면']").findall(df["질문"][i])!=[]:
            a=re.compile("[\d]{1,4}").findall(df["질문"][i])
            if int(a[0])<int(a[1]):
                df["model"][i]=[int(a[1]),"-",int(a[0])]
                df["model_answer"][i]=(int(a[1])-int(a[0]))
            elif int(a[0])>int(a[1]):
                df["model"][i]=[int(a[0]),'-',int(a[1])]
                df["model_answer"][i]=((int(a[0])-int(a[1])))
            
            
for i in range(0,len(df)):
    if re.compile("['주었더니, 하였더니']").findall(df["질문"][i])!=[]:
        if re.compile("남았습니다.").findall(df["질문"][i])!=[]:
            a=re.compile("[\d]{1,4}").findall(df["질문"][i])
            if int(a[0])<int(a[1]):
                df["model"][i]=[int(a[1]),"-",int(a[0])]
                df["model_answer"][i]=(int(a[1])-int(a[0]))
            elif int(a[0])>int(a[1]):
                df["model"][i]=[int(a[0]),'-',int(a[1])]
                df["model_answer"][i]=((int(a[0])-int(a[1])))
                
                
for i in range(0,len(df)):
    if re.compile("에게  [\w]{1,10}['을,를'] 한 [\w]{1,4}씩").findall(df["질문"][i])!=[]:
        if re.compile("몇  [\w]{1,4} 더 필요합니까").findall(df["질문"][i])!=[]:
            a=re.compile("[\d]{1,4}").findall(df["질문"][i])
            if int(a[0])<int(a[1]):
                df["model"][i]=[int(a[1]),"-",int(a[0])]
                df["model_answer"][i]=(int(a[1])-int(a[0]))
            elif int(a[0])>int(a[1]):
                df["model"][i]=[int(a[0]),'-',int(a[1])]
                df["model_answer"][i]=((int(a[0])-int(a[1])))                
              
            
                
            
for i in range(0,len(df)):
    if re.compile("와 똑같은  [\w]{1,10} 가지려면").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        if int(a[0])<int(a[1]):
            df["model"][i]=[int(a[1]),"-",int(a[0])]
            df["model_answer"][i]=(int(a[1])-int(a[0]))
        elif int(a[0])>int(a[1]):
            df["model"][i]=[int(a[0]),'-',int(a[1])]
            df["model_answer"][i]=((int(a[0])-int(a[1])))
             

for i in range(0,len(df)):
    if re.compile("와 같아질까요").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        if int(a[0])<int(a[1]):
            df["model"][i]=[int(a[1]),"-",int(a[0])]
            df["model_answer"][i]=(int(a[1])-int(a[0]))
        elif int(a[0])>int(a[1]):
            df["model"][i]=[int(a[0]),'-',int(a[1])]
            df["model_answer"][i]=((int(a[0])-int(a[1])))
             
                
for i in range(0,len(df)):
    if re.compile("같은 수의  [\w]{1,10} 갖기 위하여").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        if int(a[0])<int(a[1]):
            df["model"][i]=[int(a[1]),"-",int(a[0])]
            df["model_answer"][i]=(int(a[1])-int(a[0]))
        elif int(a[0])>int(a[1]):
            df["model"][i]=[int(a[0]),'-',int(a[1])]
            df["model_answer"][i]=((int(a[0])-int(a[1])))
            
            
for i in range(0,len(df)):
    if re.compile("만큼  [\w]{1,10}을 가지려면").findall(df["질문"][i])!=[]:
        if re.compile("만큼  [\w]{1,10}을 가지려면  [\w]{1,10} 몇 [\w]{1,4}가 더 있어야").findall(df["질문"][i])!=[]:
            a=re.compile("[\d]{1,4}").findall(df["질문"][i])
            if int(a[0])<int(a[1]):
                df["model"][i]=[int(a[1]),"-",int(a[0])]
                df["model_answer"][i]=(int(a[1])-int(a[0]))
            elif int(a[0])>int(a[1]):
                df["model"][i]=[int(a[0]),'-',int(a[1])]
                df["model_answer"][i]=((int(a[0])-int(a[1])))                 
            
            
            
for i in range(0,len(df)):
    if re.compile("['중 , 그중 , 그 중에서, 이 중, 이 중에서, 중에서']").findall(df["질문"][i])!=[]:
        if re.compile("['남았습니다, 주었습니다, 남습니까, 잃었습니다, 남은,  나가서, 부러졌습니다, 몇 [\w]{1,4}입니까']").findall(df["질문"][i])!=[]:
            a=re.compile("[\d]{1,4}").findall(df["질문"][i])
            if int(a[0])<int(a[1]):
                df["model"][i]=[int(a[1]),"-",int(a[0])]
                df["model_answer"][i]=(int(a[1])-int(a[0]))
            elif int(a[0])>int(a[1]):
                df["model"][i]=[int(a[0]),'-',int(a[1])]
                df["model_answer"][i]=((int(a[0])-int(a[1])))                 
            
            
            
for i in range(0,len(df)):
    if re.compile("['잠시 후, 얼마 후, 잠시후, 며칠 후에, 며칠 후']").findall(df["질문"][i])!=[]:
        if re.compile("['남아있는,  남았습니까, 날아갔습니다., 졌습니다, 돌아가서']").findall(df["질문"][i])!=[]:
            a=re.compile("[\d]{1,4}").findall(df["질문"][i])
            if int(a[0])<int(a[1]):
                df["model"][i]=[int(a[1]),"-",int(a[0])]
                df["model_answer"][i]=(int(a[1])-int(a[0]))
            elif int(a[0])>int(a[1]):
                df["model"][i]=[int(a[0]),'-',int(a[1])]
                df["model_answer"][i]=((int(a[0])-int(a[1])))                 
                        

                    
                    
# 더하기                    
p=['줬습니다','합','더했더니' ]
xx=['어떤', '얼마', '몇' ]

for i in range(0,len(df)):
    li=[]
    for j in range(0,len(df["kkma"][i])):
        if df["kkma"][i][j][1]=="NR" and ((df["kkma"][i][j][0]!= "이") and (df["kkma"][i][j][0]!= "몇") and (df["kkma"][i][j][0]!= "하나")): li.append(int(df["kkma"][i][j][0]))
        elif (df["kkma"][i][j][1]=="MAG") and (df["okt"][i][j][0]==h for h in p): li.append('+')
        elif (df["kkma"][i][j][1]=="MDT") and (df["okt"][i][k][0]==x  for x in xx):li.append('x')
    df["model"][i]=li
    a1=[]
    for k in df["model"][i]:
        if type(k)== int:
            a1.append(k)
    if "+" in df["model"][i]:
        res=0
        for g in a1:
            res+=g
        df["model_answer"][i]=res
    
    #예외처리
    if type(df["model"][i][-1]) == int:
        a=[]
        for k in df["model"][i]:
            if type(k)== int:
                a.append(k)
        df["model"][i]=[a[1],'-',a[0]]
        df["model_answer"][i]=(int(a[1])-int(a[0])) 
    


#예외처리
##어떤 수와 15의 합은 51
##어떤 수에 1을 더했더니 10
    elif re.compile("어떤 수와 [\d]{1,4}의 합은 [\d]{1,4}").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=[int(a[1]),'-',int(a[0])]
        df["model_answer"][i]=(int(a[1])-int(a[0]))
    elif re.compile("[\d]{1,4}와 어떤 수의 합은 [\d]{1,4}").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=[int(a[1]),'-',int(a[0])]
        df["model_answer"][i]=(int(a[1])-int(a[0]))
    elif re.compile("어떤 수에 [\d]{1,4}을 더했더니 [\d]{1,4}").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=[int(a[1]),'-',int(a[0])]
        df["model_answer"][i]=(int(a[1])-int(a[0]))
        
    elif re.compile("몇 [\w]{1,2} 더").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=[int(a[1]),'-',int(a[0])]
        df["model_answer"][i]=(int(a[1])-int(a[0]))    






            

#상자문제            
#for i in range(0,len(df)):
    elif re.compile("[\d]{1,4}['을,를'] 넣었더니 [\d]{1,4}").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        if int(a[0])<int(a[1]):
            df["model"][i]=[int(a[1]),"-",int(a[0]),'+',int(a[2])]
            df["model_answer"][i]=(int(a[1])-int(a[0])+int(a[2]))
        elif int(a[0])>int(a[1]):
            df["model"][i]=[int(a[2]),'-(',int(a[0]),'-',int(a[1]),')']
            df["model_answer"][i]=(int(a[2])-int(a[0])+int(a[1]))
    elif re.compile("[\d]{1,4}['을,를'] 넣으면 [\d]{1,4}").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        if int(a[0])<int(a[1]):
            df["model"][i]=[int(a[1]),"-",int(a[0]),'+',int(a[2])]
            df["model_answer"][i]=(int(a[1])-int(a[0])+int(a[2]))
        elif int(a[0])>int(a[1]):
            df["model"][i]=[int(a[2]),'-(',int(a[0]),'-',int(a[1]),')']
            df["model_answer"][i]=(int(a[2])-int(a[0])+int(a[1]))

# %%
#df.to_excel("a12.xlsx",index=False)
df.head()
# Out:
#                                                   질문         수식풀이  \
# 0  준기는 동화책을 어제는 58쪽，오늘은 54쪽 읽었습니다. 준기는 어제와 오늘 동화책...  58+54=[112]
# 1  곤충관에서는 곤충에게 먹이를 아침에 47봉지，점심에 69봉지를 주었습니다. 아침과 ...  47+69=[116]
# 2  나무 아래에 기린이 7마리 있습니다. 5마리가 더 온다면 모두 몇 마리인지 덧셈식을...     7+5=[12]
# 3  연수는 지금까지 훌라후프 8개를 뛰어넘었습니다. 연수가 6개를 더 뛰어넘으면 모두 ...     8+6=[14]
# 4  아름이는 사탕 15개를 가진 다운이보다 사탕이 13개 더 많습니다. 아름이가 가진 ...   15+13=[28]
#
#                                                 kkma  \
# 0  [(주, VV), (ㄴ, ETD), (길, VA), (는, ETD), (동화책, N...
# 1  [(곤충, NNG), (관, NNG), (에서, JKM), (는, JX), (곤충,...
# 2  [(나무, NNG), (아래, NNG), (에, JKM), (기린, NNG), (이...
# 3  [(연수, NNG), (는, JX), (지금, NNG), (까지, JX), (훌라후...
# 4  [(아름, NNP), (이, JKS), (늘, VV), (ㄴ, ETD), (사탕, ...
#
#                                                  okt              model  \
# 0  [(준, Noun), (기는, Verb), (동화책, Noun), (을, Josa)...     [58, 54, +, x]
# 1  [(곤충관, Noun), (에서는, Josa), (곤충, Noun), (에게, Jo...     [47, 69, +, x]
# 2  [(나무, Noun), (아래, Noun), (에, Josa), (기린, Noun)...    [7, 5, +, +, x]
# 3  [(연수, Noun), (는, Josa), (지금, Noun), (까지, Josa)...    [8, 6, +, +, x]
# 4  [(아름이, Noun), (는, Josa), (사탕, Noun), (15, Numb...  [15, +, 13, +, x]
#
#   model_answer
# 0          112
# 1          116
# 2           12
# 3           14
# 4           28

# %%
#덧셈부분이 변한다

'''
for i in range(0,len(df)):
    if re.compile('["합해, 합해서"] [\d]{1,4}').findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=['abs(',int(a[1]),'-',int(a[0]),')']
        df["model_answer"][i]=abs(int(a[1])-int(a[0]))
    elif re.compile('["합해, 합해서"] 몇').findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=['abs(',int(a[1]),'-',int(a[0]),')']
        df["model_answer"][i]=abs(int(a[1])-int(a[0]))
    elif re.compile('[\d]{1,4}와 어떤 수의 합은 [\d]{1,4}').findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=['abs(',int(a[1]),'-',int(a[0]),')']
        df["model_answer"][i]=abs(int(a[1])-int(a[0]))
    elif re.compile('[\d]{1,4}[\w]{1,4}를 합하면 [\d]{1,4}').findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=['abs(',int(a[1]),'-',int(a[0]),')']
        df["model_answer"][i]=abs(int(a[1])-int(a[0]))
        
    elif re.compile('보다 몇[\w]{1,4}  더 ["많을까요, 많습니까"]').findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=['abs(',int(a[1]),'-',int(a[0]),')']
        df["model_answer"][i]=abs(int(a[1])-int(a[0]))
    elif re.compile('보다 [\d]{1,4}[\w]{1,5} 더 ').findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=['abs(',int(a[1]),'-',int(a[0]),')']
        df["model_answer"][i]=abs(int(a[1])-int(a[0]))
    elif re.compile('똑같은 [\w]{1,10} 가지려면').findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=['abs(',int(a[1]),'-',int(a[0]),')']
        df["model_answer"][i]=abs(int(a[1])-int(a[0]))
    elif re.compile('몇 [\w]{1,10} 더 [\w]{1,10}면 [\w]{1,10}와 같아질까요').findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=['abs(',int(a[1]),'-',int(a[0]),')']
        df["model_answer"][i]=abs(int(a[1])-int(a[0]))
    elif re.compile('보다 [\w]{1,10} 몇 [\w]{1,5} 더 많이').findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=['abs(',int(a[1]),'-',int(a[0]),')']
        df["model_answer"][i]=abs(int(a[1])-int(a[0]))
        
    elif re.compile('[\d]{1,4}[\w]{1,4}에게 [\w]{1,10}을 한 [\w]{1,5}씩 [\w]{0,10} ["주려고, 나누어"] [\w]{1,30} 몇 [\w]{1,5} 더 필요').findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=['abs(',int(a[1]),'-',int(a[0]),')']
        df["model_answer"][i]=abs(int(a[1])-int(a[0]))
        
    elif re.compile('[\d]{1,4}[\w]{1,4}의 가족이 두 대의 차를 나누어 타고 놀이 공원에 가려고 합니다.  먼저 [\d]{1,4}[\w]{1,4}이 차에 타고 출발했습니다.  다른 차에 타고 출발해야 할 사람은 몇 [\w]{1,4}입니까?').findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=[int(a[0]),'-',int(a[1])]
        df["model_answer"][i]=abs(int(a[0])-int(a[1]))
        
    elif re.compile('잠시 후 [\w]{1,10} [\d]{1,4}[\w]{1,4}가   ["떠났습니다., 날아갔습니다."]  남아 있는').findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=[int(a[0]),'-',int(a[1])]
        df["model_answer"][i]=abs(int(a[0])-int(a[1]))
    elif re.compile('잠시 후  [\w]{1,10} [\d]{1,4}[\w]{1,4}가 ["떠났습니다., 날아갔습니다."]  [\w]{1,20}  몇 [\w]{1,5}  남았습니까').findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=[int(a[0]),'-',int(a[1])]
        df["model_answer"][i]=abs(int(a[0])-int(a[1]))
    elif re.compile("잠시 후 몇  [\w]{1,30}  [\d]{1,4}[\w]{1,20}  남았습니다").findall(df["질문"][i])!=[]:
        a=re.compile("[\d]{1,4}").findall(df["질문"][i])
        df["model"][i]=[int(a[0]),'-',int(a[1])]
        df["model_answer"][i]=abs(int(a[0])-int(a[1]))
'''

# %% [markdown]
# ## Kmeans

# %%
for i in range(0,len(df)):
    df["키워드1"][i]=df["키워드1"][i].strip()
    df["키워드1"][i]=list(df["키워드1"][i].split(", "))
    print(df["키워드1"][i])
# Out:
# ['모두', '몇']
# ['주었습니다', '모두', '몇']
# ['더 온다면', '몇']
# ['더 모두', '몇']
# ['보다', ' 더 많습니다', '가진', '몇']
# ['더 많습니다', '몇']
# ['더 가지고', '몇']
# ['더 많습니다', '몇']
# ['줬습니다', '모두', '몇']
# ['더 주었습니다', '모두', '몇']
# ['줬습니다', '모두', '몇']
# ['더 주었습니다', '이제', '몇']
# ['더 주었습니다', '모두', '몇']
# ['주었습니다', '이제', '몇']
# ['줬습니다', '지금', '몇']
# ['주었습니다', '모두', '몇']
# ['주었습니다', '모두', '몇']
# ['주었답니다', '모두', '몇']
# ['더', '모두', '몇']
# ['모두', '몇']
# ['더 주었습니다', '모두', '몇']
# ['주었습니다', '모두', '몇']
# ['더', '몇']
# ['모두', '몇', '몇', '더 들여왔어요.']
# ['더 넣었습니다', '모두', '몇']
# ['더 왔습니다', '모두', '몇']
# ['더 왔습니다', '모두', '몇']
# ['더 날아왔습니다', '몇']
# ['몇', '더', '모아야']
# ['몇', '더', '와서', '더 온', '몇']
# ['더 넣었습니다', '모두', '몇']
# ['더', '모두', '몇']
# ['모두', '몇']
# ['더 넣었습니다', '모두', '몇']
# ['더', '모두', '몇']
# ['상자에', '몇', '더', '모두,안에', '알맞은 수']
# ['몇', '더', '모두', '안에', '알맞은 수']
# ['몇', '더', '안에', '알맞은 수']
# ['보다', '더', '높아서', '몇']
# ['떨어진', '얼마나', '앞으로', '남아있다', '지금까지', '달려온 거리']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['두 사람', '모두', '몇']
# ['모두', '몇']
# ['두 사람', '모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['둘이', '합해', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇', '함께']
# ['모두', '몇']
# ['모두', '몇']
# ['몇', '합해', '몇']
# ['몇', '모두']
# ['갖고 있는', '몇']
# ['합해서', '몇']
# ['어떤 수의', '합']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['어떤 수', ' 합']
# ['어떤 수', ' 합']
# ['몇 ', '합']
# ['어떤 수', '더했더니']
# ['몇', '더']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['세 사람', '모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['모두', '몇']
# ['넣으면', '나오는', '상자', '넣으면', '얼마']
# ['넣었더니', '넣으면', '얼마']
# ['상자에', '넣었더니', '넣으면', '얼마']
# ['넣으면', '나오는', '상자', '넣으면', '몇']
# ['넣었더니', '넣으면', '얼마']
# ['넣었더니', '나오는', '상자', '넣으면', '얼마']
# ['넣으면', '나오는', '상자', '넣으면', '몇']
# ['넣으면', '나오는', '상자', '넣으면', '몇']
# ['넣으면', '나오는', '상자', '넣으면', '몇']
# ['넣으면', '나오는', '상자', '넣으면', '몇']
# ['넣으면', '나오는', '상자', '넣으면', '몇']
# ['넣으면', '나오는', '상자', '넣으면', '몇']
# ['넣으면', '나오는', '상자', '넣으면', '몇']
# ['넣었더니', '넣으면', '얼마']
# ['넣었더니', '넣으면', '얼마']
# ['넣었더니', '나오는', '상자에', '넣으면', '얼마']
# ['넣었더니', '나오는', '상자에', '넣으면', '얼마']
# ['넣으면', '넣으면', '몇']
# ['넣으면', '넣으면', '몇']
# ['넣으면', '넣으면', '몇']
# ['넣으면', '넣으면', '얼마']
# ['넣으면', '넣으면', '얼마']
# ['넣으면', '넣으면', '얼마']
# ['넣으면', '넣으면', '얼마']
# ['넣었더니', '넣으면', '얼마']
# ['넣었더니', '넣으면', '얼마']
# ['넣었더니', '넣으면', '얼마']
# ['상자에', '넣었더니', '넣으면', '얼마']
# ['상자에', '넣었더니', '넣으면', '얼마']
# ['상자에', '넣었더니', '넣으면', '얼마']
# ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까']
# ['넣었더니', '나오는', '넣으면', '나오겠습니까']
# ['넣었더니', '나오는', '넣으면', '나오겠습니까']
# ['넣으면', '나오는', '넣으면', '나옵니까']
# ['넣으면', '나오는', '넣으면', '나옵니까']
# ['넣으면', '나오는', '넣으면', '나오겠습니까']
# ['넣으면', '나오는', '넣으면', '나옵니까']
# ['넣으면', '나오는', '넣으면', '나옵니까']
# ['넣으면', '나오는', '넣으면', '나옵니까']
# ['넣으면', '나오는', '넣으면', '나옵니까']
# ['넣으면', '나오는', '넣으면', '나옵니까']
# ['넣으면', '나오는', '넣으면', '나옵니까']
# ['넣으면', '나오는', '넣으면', '나옵니까']
# ['넣으면', '나오는', '넣으면', '나옵니까']
# ['넣으면', '나오는', '넣으면', '나옵니까']
# ['넣으면', '나오는', '넣으면', '나옵니까']
# ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까']
# ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까']
# ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까']
# ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까']
# ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까']
# ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까']
# ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까']
# ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까']
# ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까']
# ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까']
# ['넣으면', '나옵니다', '넣으면', '나옵니까']
# ['넣으면', '나옵니다', '넣으면', '나옵니까']
# ['넣으면', '나옵니다', '넣으면', '나옵니까']
# ['넣으면', '나옵니다', '넣으면', '나옵니까']
# ['보다', '몇', '많을까요']
# ['보다', '더', '몇']
# ['보다', '많았다고', '몇']
# ['같은 수', '몇', '더']
# ['와 똑같은', '몇', '더']
# ['와 똑같은', '몇 ', '버려야']
# ['몇', '더', '같아질까요']
# ['보다', '몇', '더 많습니까']
# ['보다', '몇', '더 많습니까']
# ['보다', '몇', '더']
# ['보다', '몇 ', '더', '많을까']
# ['보다', '몇', '더', '많이']
# ['누가', '몇', '더', '많이']
# ['씩', '몇', '더,']
# ['누가', '몇', '더', '많이']
# ['보다', '많은', '몇']
# ['몇', '더', '같아질까요']
# ['보다', '몇', '더', '적습니까']
# ['보다 몇', '적습니까']
# ['누가', '몇', '많이']
# ['보다', '몇', '많습니까']
# ['만큼', '몇', '더 있어야']
# ['몇', '많은지']
# ['몇', '더']
# ['보다', '몇', '많을까요']
# ['씩', '몇', '필요합니까']
# ['보다', '몇', '많습니까']
# ['몇', '많습니까']
# ['보다', '몇', '많습니까']
# ['보다', '몇', '더', '팔았습니까']
# ['어느', '몇', '많은지']
# ['보다', '몇', '많은지']
# ['보다', '몇', '많습니까']
# ['보다', '몇', '많을까요']
# ['보다', '몇', '많을까요']
# ['보다', '몇', '많습니까']
# ['보다', '몇', '많이']
# ['보다', '몇', '많습니까']
# ['전체', '지금까지', '앞으로', '몇', '더']
# ['보다,적게', '몇']
# ['중에서', '먹었습니다', '남아 있는', '몇 장']
# ['모두', '이 중에서', '몇']
# ['중에서', '몇 ', '남았을까요']
# ['타고', '내리고', '내렸습니다', '남은', '몇']
# ['중에서', '먹었습니다', '남아 있는', '몇']
# ['사용하였습니다', '남아있는', '몇']
# ['그 중에서', '부러졌습니다', '부러지지 않은', '몇']
# ['쓰러졌다면', '쓰러지지 않은', '몇']
# ['그중에서', '먹었습니다', '남은', '몇']
# ['나누어', '몇']
# ['나누어', '몇']
# ['나누어', '몇']
# ['나누어', '몇']
# ['나오고', '나머지', '몇']
# ['중', '나머지', '몇']
# ['나누어', '몇']
# ['그 중에서', '몇', '남습니까']
# ['그 중에서', '먹었습니다', '몇', '남아 있습니까']
# ['중', '몇']
# ['나누어', '몇']
# ['더하면', '몇']
# ['더하면', '몇']
# ['모두', '몇']
# ['몇']
# ['날아갔습니다', '남아 있는', '몇']
# ['떠났습니다', '몇', '남았습니까']
# ['켜져', '꺼졌습니다', '켜져', '몇']
# ['날아갔습니다', '남아 있는', '몇']
# ['중', '남아 있는', '몇']
# ['잃었습니다', '몇']
# ['중', '먹었습니다', '남은', '몇']
# ['주었습니다', '남은', '몇']
# ['그 중에서', '잃었습니다', '남은', '몇']
# ['그 중에서', '몇', '남았습니까']
# ['남아 있는', '몇']
# ['날아갔습니다', '남아 있는', '몇']
# ['피어', '졌습니다', '피어', '몇']
# ['피어', '졌습니다', '피어', '몇']
# ['중', '주었더니', '남았습니다', '준', '몇']
# ['돌아가서', '남았습니다', '돌아간', '몇']
# ['몇', '주었습니다', '몇', '주었습니까']
# ['몇', '주었더니', '남았습니다', '준', '몇']
# ['그중', '몇', '주었습니다', '준', '몇']
# ['몇', '주고', '남았습니다', '준', '모두 몇']
# ['그 중', '몇', '주었습니다', '준', '몇']
# ['몇', '줬습니다', '몇', '준']
# ['몇', '주었더니', '남았습니다', '준', '몇']
# ['몇', '사용하였더니', '남았습니다', '사용한', '몇']
# ['중', '몇 ', '나가서', '남았습니다', '나간', '몇']
# ['몇', '주었더니', '남았습니다']

# %%
df2=df.copy()
df2.head()
# Out:
#                                                   질문  \
# 0  준기는 동화책을 어제는 58쪽，오늘은 54쪽 읽었습니다. 준기는 어제와 오늘 동화책...
# 1  곤충관에서는 곤충에게 먹이를 아침에 47봉지，점심에 69봉지를 주었습니다. 아침과 ...
# 2  나무 아래에 기린이 7마리 있습니다. 5마리가 더 온다면 모두 몇 마리인지 덧셈식을...
# 3  연수는 지금까지 훌라후프 8개를 뛰어넘었습니다. 연수가 6개를 더 뛰어넘으면 모두 ...
# 4  아름이는 사탕 15개를 가진 다운이보다 사탕이 13개 더 많습니다. 아름이가 가진 ...
#
#                              키워드                  키워드1  \
# 0             58쪽, 54쪽, 모두, 몇 쪽                [모두, 몇]
# 1    47봉지, 69봉지, 주었습니다, 모두, 몇 봉지        [주었습니다, 모두, 몇]
# 2          7마리, 5마리, 더 온다면, 몇 마리            [더 온다면, 몇]
# 3              8개, 6개, 더 모두, 몇 개             [더 모두, 몇]
# 4  15개, 보다, 13개, 더 많습니다, 가진, 몇 개  [보다,  더 많습니다, 가진, 몇]
#
#                                                 kkma  \
# 0  [(주, VV), (ㄴ, ETD), (길, VA), (는, ETD), (동화책, N...
# 1  [(곤충, NNG), (관, NNG), (에서, JKM), (는, JX), (곤충,...
# 2  [(나무, NNG), (아래, NNG), (에, JKM), (기린, NNG), (이...
# 3  [(연수, NNG), (는, JX), (지금, NNG), (까지, JX), (훌라후...
# 4  [(아름, NNP), (이, JKS), (늘, VV), (ㄴ, ETD), (사탕, ...
#
#                                                  okt              model  \
# 0  [(준, Noun), (기는, Verb), (동화책, Noun), (을, Josa)...     [58, 54, +, x]
# 1  [(곤충관, Noun), (에서는, Josa), (곤충, Noun), (에게, Jo...     [47, 69, +, x]
# 2  [(나무, Noun), (아래, Noun), (에, Josa), (기린, Noun)...    [7, 5, +, +, x]
# 3  [(연수, Noun), (는, Josa), (지금, Noun), (까지, Josa)...    [8, 6, +, +, x]
# 4  [(아름이, Noun), (는, Josa), (사탕, Noun), (15, Numb...  [15, +, 13, +, x]
#
#   model_answer
# 0          112
# 1          116
# 2           12
# 3           14
# 4           28

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
from tensorflow.keras.utils import to_categorical

# %%
len_df=len(df2)

plus2 = df2['키워드1'].values
# 정제와 단어 토큰화
vocab2={} # 파이썬의 dictionary 자료형
sentences2 = []

for i in range(len(plus2)):
    result2 =df2['키워드1'][i]
    for word in result2: 
        if word not in vocab2:
            vocab2[word] = 0 
        vocab2[word] += 1
    sentences2.append(result2)
print("vocab2\n",vocab2)

vocab_sorted2=sorted(vocab2.items(), key=lambda x:x[1], reverse=True)
print("\n\nvocab_sorted2\n",vocab_sorted2)

word_to_index2={}
i=0
for (word, frequency) in vocab_sorted2 :
    if frequency > 0 : # 정제(Cleaning) 챕터에서 언급했듯이 빈도수가 적은 단어는 제외한다.
        i=i+1
        word_to_index2[word]=i
print("\n\n word_to_index2\n",word_to_index2)

word_to_index2['OOV']=len(word_to_index2)+1

encoded2=[]
for s in sentences2:
    temp2 = []
    for w in s:
        try:
            temp2.append(word_to_index2[w])
        except KeyError:
            temp2.append(word_to_index2['OOV'])
    encoded2.append(temp2)
print("\n\nencoded2\n",encoded2)

max_len2=max(len(l) for l in encoded2) # 모든 샘플에서 길이가 가장 긴 샘플의 길이 출력
print('df2의 샘플의 최대 길이 : {}'.format(max_len2))

min_len2=min(len(l) for l in encoded2) # 모든 샘플에서 길이가 가장 긴 샘플의 길이 출력
print('df2_샘플의 최소 길이 : {}'.format(min_len2))

sequences2 = pad_sequences(encoded2, maxlen=max_len2, padding='pre')
print("sentence2\t",sentences2)

col_=[]
for i in range(1,1+int(max_len2)):
  col_.append(str(i))
col_=set(col_)

df2 = pd.DataFrame(columns=col_)

for i in range(len_df):
    df2.loc[i] = sequences2[i]

data_points2 = df2.values

print("df")
df2.head()
# Out:
# vocab2
#  {'모두': 65, '몇': 190, '주었습니다': 9, '더 온다면': 1, '더 모두': 1, '보다': 24, ' 더 많습니다': 1, '가진': 1, '더 많습니다': 2, '더 가지고': 1, '줬습니다': 4, '더 주었습니다': 4, '이제': 2, '지금': 1, '주었답니다': 1, '더': 25, '더 들여왔어요.': 1, '더 넣었습니다': 3, '더 왔습니다': 2, '더 날아왔습니다': 1, '모아야': 1, '와서': 1, '더 온': 1, '상자에': 7, '모두,안에': 1, '알맞은 수': 3, '안에': 2, '높아서': 1, '떨어진': 1, '얼마나': 1, '앞으로': 2, '남아있다': 1, '지금까지': 2, '달려온 거리': 1, '두 사람': 2, '둘이': 1, '합해': 2, '함께': 1, '갖고 있는': 1, '합해서': 1, '어떤 수의': 1, '합': 2, '어떤 수': 3, ' 합': 2, '몇 ': 5, '더했더니': 1, '세 사람': 1, '넣으면': 93, '나오는': 27, '상자': 10, '얼마': 19, '넣었더니': 27, '나왔습니다': 11, '나오겠습니까': 14, '나옵니까': 16, '나옵니다': 4, '많을까요': 4, '많았다고': 1, '같은 수': 1, '와 똑같은': 2, '버려야': 1, '같아질까요': 2, '더 많습니까': 2, '많을까': 1, '많이': 5, '누가': 3, '씩': 2, '더,': 1, '많은': 1, '적습니까': 2, '보다 몇': 1, '많습니까': 7, '만큼': 1, '더 있어야': 1, '많은지': 3, '필요합니까': 1, '팔았습니까': 1, '어느': 1, '전체': 1, '보다,적게': 1, '중에서': 3, '먹었습니다': 5, '남아 있는': 7, '몇 장': 1, '이 중에서': 1, '남았을까요': 1, '타고': 1, '내리고': 1, '내렸습니다': 1, '남은': 5, '사용하였습니다': 1, '남아있는': 1, '그 중에서': 5, '부러졌습니다': 1, '부러지지 않은': 1, '쓰러졌다면': 1, '쓰러지지 않은': 1, '그중에서': 1, '나누어': 6, '나오고': 1, '나머지': 2, '중': 6, '남습니까': 1, '남아 있습니까': 1, '더하면': 2, '날아갔습니다': 3, '떠났습니다': 1, '남았습니까': 2, '켜져': 2, '꺼졌습니다': 1, '잃었습니다': 2, '피어': 4, '졌습니다': 2, '주었더니': 4, '남았습니다': 8, '준': 7, '돌아가서': 1, '돌아간': 1, '주었습니까': 1, '그중': 1, '주고': 1, '모두 몇': 1, '그 중': 1, '사용하였더니': 1, '사용한': 1, '나가서': 1, '나간': 1}
#
#
# vocab_sorted2
#  [('몇', 190), ('넣으면', 93), ('모두', 65), ('나오는', 27), ('넣었더니', 27), ('더', 25), ('보다', 24), ('얼마', 19), ('나옵니까', 16), ('나오겠습니까', 14), ('나왔습니다', 11), ('상자', 10), ('주었습니다', 9), ('남았습니다', 8), ('상자에', 7), ('많습니까', 7), ('남아 있는', 7), ('준', 7), ('나누어', 6), ('중', 6), ('몇 ', 5), ('많이', 5), ('먹었습니다', 5), ('남은', 5), ('그 중에서', 5), ('줬습니다', 4), ('더 주었습니다', 4), ('나옵니다', 4), ('많을까요', 4), ('피어', 4), ('주었더니', 4), ('더 넣었습니다', 3), ('알맞은 수', 3), ('어떤 수', 3), ('누가', 3), ('많은지', 3), ('중에서', 3), ('날아갔습니다', 3), ('더 많습니다', 2), ('이제', 2), ('더 왔습니다', 2), ('안에', 2), ('앞으로', 2), ('지금까지', 2), ('두 사람', 2), ('합해', 2), ('합', 2), (' 합', 2), ('와 똑같은', 2), ('같아질까요', 2), ('더 많습니까', 2), ('씩', 2), ('적습니까', 2), ('나머지', 2), ('더하면', 2), ('남았습니까', 2), ('켜져', 2), ('잃었습니다', 2), ('졌습니다', 2), ('더 온다면', 1), ('더 모두', 1), (' 더 많습니다', 1), ('가진', 1), ('더 가지고', 1), ('지금', 1), ('주었답니다', 1), ('더 들여왔어요.', 1), ('더 날아왔습니다', 1), ('모아야', 1), ('와서', 1), ('더 온', 1), ('모두,안에', 1), ('높아서', 1), ('떨어진', 1), ('얼마나', 1), ('남아있다', 1), ('달려온 거리', 1), ('둘이', 1), ('함께', 1), ('갖고 있는', 1), ('합해서', 1), ('어떤 수의', 1), ('더했더니', 1), ('세 사람', 1), ('많았다고', 1), ('같은 수', 1), ('버려야', 1), ('많을까', 1), ('더,', 1), ('많은', 1), ('보다 몇', 1), ('만큼', 1), ('더 있어야', 1), ('필요합니까', 1), ('팔았습니까', 1), ('어느', 1), ('전체', 1), ('보다,적게', 1), ('몇 장', 1), ('이 중에서', 1), ('남았을까요', 1), ('타고', 1), ('내리고', 1), ('내렸습니다', 1), ('사용하였습니다', 1), ('남아있는', 1), ('부러졌습니다', 1), ('부러지지 않은', 1), ('쓰러졌다면', 1), ('쓰러지지 않은', 1), ('그중에서', 1), ('나오고', 1), ('남습니까', 1), ('남아 있습니까', 1), ('떠났습니다', 1), ('꺼졌습니다', 1), ('돌아가서', 1), ('돌아간', 1), ('주었습니까', 1), ('그중', 1), ('주고', 1), ('모두 몇', 1), ('그 중', 1), ('사용하였더니', 1), ('사용한', 1), ('나가서', 1), ('나간', 1)]
#
#
#  word_to_index2
#  {'몇': 1, '넣으면': 2, '모두': 3, '나오는': 4, '넣었더니': 5, '더': 6, '보다': 7, '얼마': 8, '나옵니까': 9, '나오겠습니까': 10, '나왔습니다': 11, '상자': 12, '주었습니다': 13, '남았습니다': 14, '상자에': 15, '많습니까': 16, '남아 있는': 17, '준': 18, '나누어': 19, '중': 20, '몇 ': 21, '많이': 22, '먹었습니다': 23, '남은': 24, '그 중에서': 25, '줬습니다': 26, '더 주었습니다': 27, '나옵니다': 28, '많을까요': 29, '피어': 30, '주었더니': 31, '더 넣었습니다': 32, '알맞은 수': 33, '어떤 수': 34, '누가': 35, '많은지': 36, '중에서': 37, '날아갔습니다': 38, '더 많습니다': 39, '이제': 40, '더 왔습니다': 41, '안에': 42, '앞으로': 43, '지금까지': 44, '두 사람': 45, '합해': 46, '합': 47, ' 합': 48, '와 똑같은': 49, '같아질까요': 50, '더 많습니까': 51, '씩': 52, '적습니까': 53, '나머지': 54, '더하면': 55, '남았습니까': 56, '켜져': 57, '잃었습니다': 58, '졌습니다': 59, '더 온다면': 60, '더 모두': 61, ' 더 많습니다': 62, '가진': 63, '더 가지고': 64, '지금': 65, '주었답니다': 66, '더 들여왔어요.': 67, '더 날아왔습니다': 68, '모아야': 69, '와서': 70, '더 온': 71, '모두,안에': 72, '높아서': 73, '떨어진': 74, '얼마나': 75, '남아있다': 76, '달려온 거리': 77, '둘이': 78, '함께': 79, '갖고 있는': 80, '합해서': 81, '어떤 수의': 82, '더했더니': 83, '세 사람': 84, '많았다고': 85, '같은 수': 86, '버려야': 87, '많을까': 88, '더,': 89, '많은': 90, '보다 몇': 91, '만큼': 92, '더 있어야': 93, '필요합니까': 94, '팔았습니까': 95, '어느': 96, '전체': 97, '보다,적게': 98, '몇 장': 99, '이 중에서': 100, '남았을까요': 101, '타고': 102, '내리고': 103, '내렸습니다': 104, '사용하였습니다': 105, '남아있는': 106, '부러졌습니다': 107, '부러지지 않은': 108, '쓰러졌다면': 109, '쓰러지지 않은': 110, '그중에서': 111, '나오고': 112, '남습니까': 113, '남아 있습니까': 114, '떠났습니다': 115, '꺼졌습니다': 116, '돌아가서': 117, '돌아간': 118, '주었습니까': 119, '그중': 120, '주고': 121, '모두 몇': 122, '그 중': 123, '사용하였더니': 124, '사용한': 125, '나가서': 126, '나간': 127}
#
#
# encoded2
#  [[3, 1], [13, 3, 1], [60, 1], [61, 1], [7, 62, 63, 1], [39, 1], [64, 1], [39, 1], [26, 3, 1], [27, 3, 1], [26, 3, 1], [27, 40, 1], [27, 3, 1], [13, 40, 1], [26, 65, 1], [13, 3, 1], [13, 3, 1], [66, 3, 1], [6, 3, 1], [3, 1], [27, 3, 1], [13, 3, 1], [6, 1], [3, 1, 1, 67], [32, 3, 1], [41, 3, 1], [41, 3, 1], [68, 1], [1, 6, 69], [1, 6, 70, 71, 1], [32, 3, 1], [6, 3, 1], [3, 1], [32, 3, 1], [6, 3, 1], [15, 1, 6, 72, 33], [1, 6, 3, 42, 33], [1, 6, 42, 33], [7, 6, 73, 1], [74, 75, 43, 76, 44, 77], [3, 1], [3, 1], [3, 1], [3, 1], [45, 3, 1], [3, 1], [45, 3, 1], [3, 1], [3, 1], [3, 1], [3, 1], [3, 1], [3, 1], [3, 1], [3, 1], [78, 46, 1], [3, 1], [3, 1], [3, 1], [3, 1], [3, 1], [3, 1], [3, 1, 79], [3, 1], [3, 1], [1, 46, 1], [1, 3], [80, 1], [81, 1], [82, 47], [3, 1], [3, 1], [3, 1], [3, 1], [3, 1], [34, 48], [34, 48], [21, 47], [34, 83], [1, 6], [3, 1], [3, 1], [3, 1], [3, 1], [3, 1], [3, 1], [84, 3, 1], [3, 1], [3, 1], [3, 1], [2, 4, 12, 2, 8], [5, 2, 8], [15, 5, 2, 8], [2, 4, 12, 2, 1], [5, 2, 8], [5, 4, 12, 2, 8], [2, 4, 12, 2, 1], [2, 4, 12, 2, 1], [2, 4, 12, 2, 1], [2, 4, 12, 2, 1], [2, 4, 12, 2, 1], [2, 4, 12, 2, 1], [2, 4, 12, 2, 1], [5, 2, 8], [5, 2, 8], [5, 4, 15, 2, 8], [5, 4, 15, 2, 8], [2, 2, 1], [2, 2, 1], [2, 2, 1], [2, 2, 8], [2, 2, 8], [2, 2, 8], [2, 2, 8], [5, 2, 8], [5, 2, 8], [5, 2, 8], [15, 5, 2, 8], [15, 5, 2, 8], [15, 5, 2, 8], [5, 11, 2, 10], [5, 4, 2, 10], [5, 4, 2, 10], [2, 4, 2, 9], [2, 4, 2, 9], [2, 4, 2, 10], [2, 4, 2, 9], [2, 4, 2, 9], [2, 4, 2, 9], [2, 4, 2, 9], [2, 4, 2, 9], [2, 4, 2, 9], [2, 4, 2, 9], [2, 4, 2, 9], [2, 4, 2, 9], [2, 4, 2, 9], [5, 11, 2, 10], [5, 11, 2, 10], [5, 11, 2, 10], [5, 11, 2, 10], [5, 11, 2, 10], [5, 11, 2, 10], [5, 11, 2, 10], [5, 11, 2, 10], [5, 11, 2, 10], [5, 11, 2, 10], [2, 28, 2, 9], [2, 28, 2, 9], [2, 28, 2, 9], [2, 28, 2, 9], [7, 1, 29], [7, 6, 1], [7, 85, 1], [86, 1, 6], [49, 1, 6], [49, 21, 87], [1, 6, 50], [7, 1, 51], [7, 1, 51], [7, 1, 6], [7, 21, 6, 88], [7, 1, 6, 22], [35, 1, 6, 22], [52, 1, 89], [35, 1, 6, 22], [7, 90, 1], [1, 6, 50], [7, 1, 6, 53], [91, 53], [35, 1, 22], [7, 1, 16], [92, 1, 93], [1, 36], [1, 6], [7, 1, 29], [52, 1, 94], [7, 1, 16], [1, 16], [7, 1, 16], [7, 1, 6, 95], [96, 1, 36], [7, 1, 36], [7, 1, 16], [7, 1, 29], [7, 1, 29], [7, 1, 16], [7, 1, 22], [7, 1, 16], [97, 44, 43, 1, 6], [98, 1], [37, 23, 17, 99], [3, 100, 1], [37, 21, 101], [102, 103, 104, 24, 1], [37, 23, 17, 1], [105, 106, 1], [25, 107, 108, 1], [109, 110, 1], [111, 23, 24, 1], [19, 1], [19, 1], [19, 1], [19, 1], [112, 54, 1], [20, 54, 1], [19, 1], [25, 1, 113], [25, 23, 1, 114], [20, 1], [19, 1], [55, 1], [55, 1], [3, 1], [1], [38, 17, 1], [115, 1, 56], [57, 116, 57, 1], [38, 17, 1], [20, 17, 1], [58, 1], [20, 23, 24, 1], [13, 24, 1], [25, 58, 24, 1], [25, 1, 56], [17, 1], [38, 17, 1], [30, 59, 30, 1], [30, 59, 30, 1], [20, 31, 14, 18, 1], [117, 14, 118, 1], [1, 13, 1, 119], [1, 31, 14, 18, 1], [120, 1, 13, 18, 1], [1, 121, 14, 18, 122], [123, 1, 13, 18, 1], [1, 26, 1, 18], [1, 31, 14, 18, 1], [1, 124, 14, 125, 1], [20, 21, 126, 14, 127, 1], [1, 31, 14]]
# df2의 샘플의 최대 길이 : 6
# df2_샘플의 최소 길이 : 1
# sentence2	 [['모두', '몇'], ['주었습니다', '모두', '몇'], ['더 온다면', '몇'], ['더 모두', '몇'], ['보다', ' 더 많습니다', '가진', '몇'], ['더 많습니다', '몇'], ['더 가지고', '몇'], ['더 많습니다', '몇'], ['줬습니다', '모두', '몇'], ['더 주었습니다', '모두', '몇'], ['줬습니다', '모두', '몇'], ['더 주었습니다', '이제', '몇'], ['더 주었습니다', '모두', '몇'], ['주었습니다', '이제', '몇'], ['줬습니다', '지금', '몇'], ['주었습니다', '모두', '몇'], ['주었습니다', '모두', '몇'], ['주었답니다', '모두', '몇'], ['더', '모두', '몇'], ['모두', '몇'], ['더 주었습니다', '모두', '몇'], ['주었습니다', '모두', '몇'], ['더', '몇'], ['모두', '몇', '몇', '더 들여왔어요.'], ['더 넣었습니다', '모두', '몇'], ['더 왔습니다', '모두', '몇'], ['더 왔습니다', '모두', '몇'], ['더 날아왔습니다', '몇'], ['몇', '더', '모아야'], ['몇', '더', '와서', '더 온', '몇'], ['더 넣었습니다', '모두', '몇'], ['더', '모두', '몇'], ['모두', '몇'], ['더 넣었습니다', '모두', '몇'], ['더', '모두', '몇'], ['상자에', '몇', '더', '모두,안에', '알맞은 수'], ['몇', '더', '모두', '안에', '알맞은 수'], ['몇', '더', '안에', '알맞은 수'], ['보다', '더', '높아서', '몇'], ['떨어진', '얼마나', '앞으로', '남아있다', '지금까지', '달려온 거리'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['두 사람', '모두', '몇'], ['모두', '몇'], ['두 사람', '모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['둘이', '합해', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇', '함께'], ['모두', '몇'], ['모두', '몇'], ['몇', '합해', '몇'], ['몇', '모두'], ['갖고 있는', '몇'], ['합해서', '몇'], ['어떤 수의', '합'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['어떤 수', ' 합'], ['어떤 수', ' 합'], ['몇 ', '합'], ['어떤 수', '더했더니'], ['몇', '더'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['세 사람', '모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['모두', '몇'], ['넣으면', '나오는', '상자', '넣으면', '얼마'], ['넣었더니', '넣으면', '얼마'], ['상자에', '넣었더니', '넣으면', '얼마'], ['넣으면', '나오는', '상자', '넣으면', '몇'], ['넣었더니', '넣으면', '얼마'], ['넣었더니', '나오는', '상자', '넣으면', '얼마'], ['넣으면', '나오는', '상자', '넣으면', '몇'], ['넣으면', '나오는', '상자', '넣으면', '몇'], ['넣으면', '나오는', '상자', '넣으면', '몇'], ['넣으면', '나오는', '상자', '넣으면', '몇'], ['넣으면', '나오는', '상자', '넣으면', '몇'], ['넣으면', '나오는', '상자', '넣으면', '몇'], ['넣으면', '나오는', '상자', '넣으면', '몇'], ['넣었더니', '넣으면', '얼마'], ['넣었더니', '넣으면', '얼마'], ['넣었더니', '나오는', '상자에', '넣으면', '얼마'], ['넣었더니', '나오는', '상자에', '넣으면', '얼마'], ['넣으면', '넣으면', '몇'], ['넣으면', '넣으면', '몇'], ['넣으면', '넣으면', '몇'], ['넣으면', '넣으면', '얼마'], ['넣으면', '넣으면', '얼마'], ['넣으면', '넣으면', '얼마'], ['넣으면', '넣으면', '얼마'], ['넣었더니', '넣으면', '얼마'], ['넣었더니', '넣으면', '얼마'], ['넣었더니', '넣으면', '얼마'], ['상자에', '넣었더니', '넣으면', '얼마'], ['상자에', '넣었더니', '넣으면', '얼마'], ['상자에', '넣었더니', '넣으면', '얼마'], ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까'], ['넣었더니', '나오는', '넣으면', '나오겠습니까'], ['넣었더니', '나오는', '넣으면', '나오겠습니까'], ['넣으면', '나오는', '넣으면', '나옵니까'], ['넣으면', '나오는', '넣으면', '나옵니까'], ['넣으면', '나오는', '넣으면', '나오겠습니까'], ['넣으면', '나오는', '넣으면', '나옵니까'], ['넣으면', '나오는', '넣으면', '나옵니까'], ['넣으면', '나오는', '넣으면', '나옵니까'], ['넣으면', '나오는', '넣으면', '나옵니까'], ['넣으면', '나오는', '넣으면', '나옵니까'], ['넣으면', '나오는', '넣으면', '나옵니까'], ['넣으면', '나오는', '넣으면', '나옵니까'], ['넣으면', '나오는', '넣으면', '나옵니까'], ['넣으면', '나오는', '넣으면', '나옵니까'], ['넣으면', '나오는', '넣으면', '나옵니까'], ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까'], ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까'], ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까'], ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까'], ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까'], ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까'], ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까'], ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까'], ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까'], ['넣었더니', '나왔습니다', '넣으면', '나오겠습니까'], ['넣으면', '나옵니다', '넣으면', '나옵니까'], ['넣으면', '나옵니다', '넣으면', '나옵니까'], ['넣으면', '나옵니다', '넣으면', '나옵니까'], ['넣으면', '나옵니다', '넣으면', '나옵니까'], ['보다', '몇', '많을까요'], ['보다', '더', '몇'], ['보다', '많았다고', '몇'], ['같은 수', '몇', '더'], ['와 똑같은', '몇', '더'], ['와 똑같은', '몇 ', '버려야'], ['몇', '더', '같아질까요'], ['보다', '몇', '더 많습니까'], ['보다', '몇', '더 많습니까'], ['보다', '몇', '더'], ['보다', '몇 ', '더', '많을까'], ['보다', '몇', '더', '많이'], ['누가', '몇', '더', '많이'], ['씩', '몇', '더,'], ['누가', '몇', '더', '많이'], ['보다', '많은', '몇'], ['몇', '더', '같아질까요'], ['보다', '몇', '더', '적습니까'], ['보다 몇', '적습니까'], ['누가', '몇', '많이'], ['보다', '몇', '많습니까'], ['만큼', '몇', '더 있어야'], ['몇', '많은지'], ['몇', '더'], ['보다', '몇', '많을까요'], ['씩', '몇', '필요합니까'],  ...
# df
#    6  4  1   2   5  3
# 0  0  0  0   0   3  1
# 1  0  0  0  13   3  1
# 2  0  0  0   0  60  1
# 3  0  0  0   0  61  1
# 4  0  0  7  62  63  1

# %%
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans

# %%
def elbow(X):
    sse=[]
    for i in range(1,11):
        km=KMeans(n_clusters=i,init="k-means++",random_state=0)
        km.fit(X)
        sse.append(km.inertia_)
    plt.plot(range(1, 11),sse,marker="o")
    plt.show()

# %%
elbow(data_points2) #더하기 빼기

# %%
kmeans = KMeans(n_clusters = 6).fit(data_points2)
df2['kmeans'] = kmeans.labels_
df2.to_excel('k2.xlsx',index=False)
